# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
weather_api_key = "4ec6d8e1ae81121aede0df10f12e834e"
weather_api_key
# Out:
# '4ec6d8e1ae81121aede0df10f12e834e'

# %%
from citipy import citipy

# %%
output_data_file = "out_put/cities.csv"
lat_range = (-90,90)
lng_range = (-180,180)
print(weather_api_key)
# Out:
# 4ec6d8e1ae81121aede0df10f12e834e

# %%
#List for holding lat_lngs and cities
lat_lngs = []
cities = []
#create a set of random lat long combo's
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

#identify nearest city for each lat & lng combo
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     if the city is unique append(add to the cities list)
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 629

# %%
#generate city list
cities
# Out:
# ['oksbol',
#  'chokurdakh',
#  'grahamstown',
#  'mount gambier',
#  'asau',
#  'bilibino',
#  'tsihombe',
#  'tobetsu',
#  'pangnirtung',
#  'bluff',
#  'new norfolk',
#  'touros',
#  'maniitsoq',
#  'havre-saint-pierre',
#  'mehamn',
#  'albany',
#  'cape town',
#  'wodonga',
#  'busselton',
#  'terme',
#  'salalah',
#  'lebu',
#  'ust-nera',
#  'aswan',
#  'galgani',
#  'uige',
#  'sao joao da barra',
#  'dikson',
#  'homer',
#  'ushuaia',
#  'butaritari',
#  'lasa',
#  'coihaique',
#  'qaqortoq',
#  'comayagua',
#  'punta arenas',
#  'agadir',
#  'dunedin',
#  'fort frances',
#  'nikolskoye',
#  'puerto ayora',
#  'kysyl-syr',
#  'korla',
#  'teknaf',
#  'attawapiskat',
#  'avera',
#  'russell',
#  'mataura',
#  'namatanai',
#  'luganville',
#  'port elizabeth',
#  'nelson bay',
#  'caravelas',
#  'tecoh',
#  'aybak',
#  'atuona',
#  'porto torres',
#  'khatanga',
#  'port alfred',
#  'pevek',
#  'jamestown',
#  'grindavik',
#  'kalianget',
#  'santa isabel do rio negro',
#  'kruisfontein',
#  'rikitea',
#  'aflu',
#  'gamba',
#  'agadez',
#  'opuwo',
#  'bredasdorp',
#  'novo aripuana',
#  'tessalit',
#  'hambantota',
#  'lieksa',
#  'inuvik',
#  'klaksvik',
#  'prince albert',
#  'bethel',
#  'hilo',
#  'omboue',
#  'wenchi',
#  'tuktoyaktuk',
#  'ajdabiya',
#  'arrecife',
#  'belushya guba',
#  'nam tha',
#  'luderitz',
#  'coquimbo',
#  'strezhevoy',
#  'saldanha',
#  'taihe',
#  'kapaa',
#  'plainview',
#  'georgetown',
#  'kodinsk',
#  'knysna',
#  'provideniya',
#  'chervone',
#  'sinnai',
#  'mumford',
#  'upernavik',
#  'constitucion',
#  'hobart',
#  'russellville',
#  'debre tabor',
#  'road town',
#  'port moresby',
#  'beringovskiy',
#  'taolanaro',
#  'siavonga',
#  'sentyabrskiy',
#  'thompson',
#  'palmerston',
#  'bolshoye murashkino',
#  'ixtapa',
#  'bani',
#  'rawson',
#  'santa marta',
#  'amderma',
#  'delvada',
#  'norman wells',
#  'halifax',
#  'arraial do cabo',
#  'saint-pierre',
#  'carnarvon',
#  'mincivan',
#  'barentsburg',
#  'airai',
#  'sernur',
#  'nabire',
#  'iqaluit',
#  'deming',
#  'tasbuget',
#  'daru',
#  'palmer',
#  'yellowknife',
#  'cervo',
#  'chimoio',
#  'katobu',
#  'balabac',
#  'ahipara',
#  'tuy hoa',
#  'comodoro rivadavia',
#  'ballymena',
#  'ostrovnoy',
#  'clyde river',
#  'mahebourg',
#  'eau claire',
#  'longyearbyen',
#  'vaini',
#  'tasiilaq',
#  'salisbury',
#  'mar del plata',
#  'hermanus',
#  'ngukurr',
#  'shatrovo',
#  'eydhafushi',
#  'nanakuli',
#  'solnechnyy',
#  'kodiak',
#  'hiji',
#  'saint george',
#  'jiroft',
#  'bambous virieux',
#  'pauini',
#  'majene',
#  'joensuu',
#  'avarua',
#  'el higo',
#  'san patricio',
#  'vardo',
#  'ribeira grande',
#  'jacareacanga',
#  'san policarpo',
#  'yaan',
#  'tual',
#  'illoqqortoormiut',
#  'baruun-urt',
#  'biltine',
#  'ayagoz',
#  'kankavli',
#  'vung tau',
#  'lavrentiya',
#  'mys shmidta',
#  'torbay',
#  'belmonte',
#  'mudyuga',
#  'fortuna',
#  'lingao',
#  'tabuleiro do norte',
#  'abilene',
#  'tuyen quang',
#  'tlacotepec',
#  'westport',
#  'baiao',
#  'sinnamary',
#  'nome',
#  'riyadh',
#  'orsha',
#  'cookeville',
#  'chuy',
#  'ancud',
#  'paita',
#  'cayenne',
#  'cabo san lucas',
#  'severo-kurilsk',
#  'abashiri',
#  'taltal',
#  'hofn',
#  'necochea',
#  'bara',
#  'esperance',
#  'eston',
#  'krasnyy chikoy',
#  'udachnyy',
#  'urdzhar',
#  'maridi',
#  'port lincoln',
#  'buala',
#  'narsaq',
#  'scalea',
#  'mogadishu',
#  'yar-sale',
#  'ola',
#  'mamallapuram',
#  'idlib',
#  'saint-augustin',
#  'dingle',
#  'faanui',
#  'belen',
#  'coracao de jesus',
#  'ponta do sol',
#  'armacao dos buzios',
#  'contramaestre',
#  'kamenka',
#  'kuche',
#  'mount isa',
#  'beian',
#  'sosva',
#  'pueblo nuevo',
#  'bathsheba',
#  'hithadhoo',
#  'hovd',
#  'huancavelica',
#  'mukhen',
#  'rossland',
#  'ust-barguzin',
#  'tilichiki',
#  'college',
#  'brumadinho',
#  'zemaiciu naumiestis',
#  'kendari',
#  'iralaya',
#  'cherskiy',
#  'chiredzi',
#  'axim',
#  'jalu',
#  'kulhudhuffushi',
#  'grand gaube',
#  'okha',
#  'astipalaia',
#  'ternate',
#  'andenes',
#  'leningradskiy',
#  'souillac',
#  'gizo',
#  'cockburn town',
#  'flinders',
#  'lanxi',
#  'francisco sa',
#  'novyy urengoy',
#  'sorland',
#  'baculin',
#  'honningsvag',
#  'victoria',
#  'shaturtorf',
#  'port blair',
#  'tura',
#  'bengkulu',
#  'ucluelet',
#  'pisco',
#  'zalantun',
#  'reyes',
#  'poya',
#  'umzimvubu',
#  'gogrial',
#  'rohatyn',
#  'lompoc',
#  'mancio lima',
#  'naryan-mar',
#  'manzil salim',
#  'rio grande',
#  'rio rancho',
#  'hasaki',
#  'geraldton',
#  'gat',
#  'barrow',
#  'kamennomostskiy',
#  'carauari',
#  'dicabisagan',
#  'sao filipe',
#  'rancho palos verdes',
#  'tezu',
#  'grand river south east',
#  'nanortalik',
#  'tatarskaya kargala',
#  'lebyazhye',
#  'aklavik',
#  'camacha',
#  'colares',
#  'vila',
#  'tarko-sale',
#  'barmer',
#  'roros',
#  'garissa',
#  'hihifo',
#  'maceio',
#  'saint-philippe',
#  'tumannyy',
#  'tecoanapa',
#  'dzhalil',
#  'qasigiannguit',
#  'petropavlovsk-kamchatskiy',
#  'marinette',
#  'sukhobezvodnoye',
#  'umm kaddadah',
#  'felidhoo',
#  'pemberton',
#  'meadow lake',
#  'deputatskiy',
#  'nizhneyansk',
#  'anqing',
#  'dehloran',
#  'vestmannaeyjar',
#  'qaanaaq',
#  'binga',
#  'marsaxlokk',
#  'leeton',
#  'jiujiang',
#  'shingu',
#  'kavaratti',
#  'novoagansk',
#  'levelland',
#  'bilma',
#  'petrolandia',
#  'rocha',
#  'valparaiso',
#  'talen',
#  'arrifes',
#  'yenagoa',
#  'dolbeau',
#  'vao',
#  'hluti',
#  'fort nelson',
#  'richards bay',
#  'viligili',
#  'castro',
#  'nemuro',
#  'chagda',
#  'manggar',
#  'vega de alatorre',
#  'cavalcante',
#  'luwuk',
#  'meulaboh',
#  'amapa',
#  'iranshahr',
#  'strai',
#  'chumphon',
#  'palabuhanratu',
#  'tiarei',
#  'dhar',
#  'vila franca do campo',
#  'pierre',
#  'tabiauea',
#  'puerto escondido',
#  'labutta',
#  'sao felix do xingu',
#  'mandal',
#  'gomel',
#  'cabedelo',
#  'cucer',
#  'ambajogai',
#  'los andes',
#  'quatre cocos',
#  'kambove',
#  'east london',
#  'te anau',
#  'nyaunglebin',
#  'buarcos',
#  'cortes',
#  'nova role',
#  'tuatapere',
#  'okhotsk',
#  'port hardy',
#  'nyurba',
#  'gori',
#  'ahuimanu',
#  'salina',
#  'mchinji',
#  'kaitangata',
#  'kifri',
#  'kenitra',
#  'zenzeli',
#  'gazli',
#  'los llanos de aridane',
#  'esso',
#  'melioratorov',
#  'baglung',
#  'anloga',
#  'krasnogorsk',
#  'wuchang',
#  'havoysund',
#  'ilulissat',
#  'stryn',
#  'gimli',
#  'grenfell',
#  'tucuma',
#  'mandan',
#  'casablanca',
#  'tiksi',
#  'srednekolymsk',
#  'praia da vitoria',
#  'pacifica',
#  'mayumba',
#  'suratgarh',
#  'sitia',
#  'fare',
#  'sheopur',
#  'porto seguro',
#  'kahului',
#  'kemi',
#  'waipawa',
#  'aksu',
#  'dera bugti',
#  'hargeysa',
#  'eirunepe',
#  'baykit',
#  'horsham',
#  'condado',
#  'ginda',
#  'tjome',
#  'vaitupu',
#  'marcona',
#  'lamu',
#  'visavadar',
#  'zyryanka',
#  'sabang',
#  'villa rica',
#  'arlit',
#  'canakkale',
#  'saskylakh',
#  'vilhena',
#  'grenada',
#  'nizhniy kuranakh',
#  'bentonville',
#  'bireun',
#  'margate',
#  'isangel',
#  'ziro',
#  'baijiantan',
#  'tocopilla',
#  'noumea',
#  'samarai',
#  'marzuq',
#  'balkanabat',
#  'west wendover',
#  'northam',
#  'manicore',
#  'kenai',
#  'nishihara',
#  'volchansk',
#  'walvis bay',
#  'samusu',
#  'rungata',
#  'oriximina',
#  'tabas',
#  'winnemucca',
#  'lorengau',
#  'baie-comeau',
#  'carlos chagas',
#  'brae',
#  'suntar',
#  'batagay-alyta',
#  'san pedro',
#  'padang',
#  'belyy yar',
#  'muros',
#  'zhigansk',
#  'chicama',
#  'taft',
#  'san roque',
#  'broome',
#  'hope',
#  'olinda',
#  'safwah',
#  'wigston',
#  'collie',
#  'vanimo',
#  'vyartsilya',
#  'matamoros',
#  'ventspils',
#  'cazaje',
#  'kavieng',
#  'zhezkazgan',
#  'carnot',
#  'cheuskiny',
#  'ahumada',
#  'boralday',
#  'pangody',
#  'charlestown',
#  'saint-francois',
#  'cidreira',
#  'san cristobal',
#  'tidore',
#  'bend',
#  'kawalu',
#  'codrington',
#  'namibe',
#  'tucumcari',
#  'aksarka',
#  'ponta delgada',
#  'kolosovka',
#  'yarada',
#  'lagoa',
#  'sataua',
#  'le port',
#  'kaeo',
#  'grazhdanskoye pervoye',
#  'campoverde',
#  'enshi',
#  'menongue',
#  'alofi',
#  'tefe',
#  'yumen',
#  'kayunga',
#  'setermoen',
#  'shu',
#  'bose',
#  'burica',
#  'catalina foothills',
#  'warqla',
#  'nchelenge',
#  'esmeraldas',
#  'champerico',
#  'trincomalee',
#  'chirongui',
#  'kaspiyskiy',
#  'chara',
#  'la asuncion',
#  'erenhot',
#  'babati',
#  'saleaula',
#  'qandahar',
#  'cheyenne',
#  'kismayo',
#  'bow island',
#  'bandarbeyla',
#  'pangai',
#  'moron',
#  'port-gentil',
#  'tsaratanana',
#  'tornio',
#  'dali',
#  'henties bay',
#  'gambissara',
#  'gore',
#  'zapolyarnyy',
#  'newport',
#  'kananga',
#  'hualmay',
#  'chuncheng',
#  'la quinta',
#  'la rioja',
#  'karratha',
#  'tautira',
#  'luba',
#  'jutai',
#  'murmino',
#  'paarl',
#  'charkhari',
#  'kudahuvadhoo',
#  'saint anthony',
#  'ust-tsilma',
#  'urucara',
#  'maxixe',
#  'kentau',
#  'kontagora',
#  'duku',
#  'barcelos',
#  'camopi',
#  'kungurtug',
#  'bambanglipuro',
#  'enumclaw',
#  'ulaangom',
#  'batemans bay',
#  'bima',
#  'kamenskoye',
#  'bonthe',
#  'terre-de-bas',
#  'chadan',
#  'scarborough',
#  'susanville',
#  'sovetskaya gavan',
#  'sarlat-la-caneda',
#  'banda aceh',
#  'genc',
#  'sandwick',
#  'sao francisco de assis',
#  'atambua',
#  'tondano',
#  'gaziantep',
#  'karaul',
#  'louisbourg',
#  'taoudenni',
#  'acandi',
#  'zaraza',
#  'okoneshnikovo',
#  'cap malheureux',
#  'kargasok',
#  'kalmunai',
#  'pacific grove',
#  'joshimath',
#  'ovsyanka',
#  'toliary',
#  'dabola',
#  'vila velha',
#  'kyra',
#  'waingapu']

# %%
#starting URL to pull api call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ec6d8e1ae81121aede0df10f12e834e"
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ec6d8e1ae81121aede0df10f12e834e'

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4ec6d8e1ae81121aede0df10f12e834e'

# %%
#list of data
city_data = []

#print to logger
print("Beginner Data Retrieval")
print("---------------")
#don't forget spacing ***python forloop has to be inside of forloop until the end

#counters
record_count = 1
set_count = 1

#loop through cities (enumerate = going through cities one by one)
for i, city in enumerate(cities):
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 0
        
    #create endpoint URL with each city
    city_url = url + "&q=" + city
    
    #log the url, record and set number (where ever you see % pass the array (items) below every time)
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    #add 1 to the record count (what is was plus one)
    record_count += 1
    
    #run an API request for each of the cities
    try:
        #parse the JSON and retrieve 
        city_weather = requests.get(city_url).json()
                 
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
                                
        #if city not found go to next
    except:
        print("City not found, move on to the next...")
        pass
        
#indicate data loading is done
print("-------------------")
print("Data Retrieval Complete")
print("--------------------")
# Out:
# Beginner Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | oksbol
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | grahamstown
# Processing Record 4 of Set 1 | mount gambier
# Processing Record 5 of Set 1 | asau
# Processing Record 6 of Set 1 | bilibino
# Processing Record 7 of Set 1 | tsihombe
# City not found, move on to the next...
# Processing Record 8 of Set 1 | tobetsu
# Processing Record 9 of Set 1 | pangnirtung
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | touros
# Processing Record 13 of Set 1 | maniitsoq
# Processing Record 14 of Set 1 | havre-saint-pierre
# Processing Record 15 of Set 1 | mehamn
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | wodonga
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | terme
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | ust-nera
# Processing Record 24 of Set 1 | aswan
# Processing Record 25 of Set 1 | galgani
# City not found, move on to the next...
# Processing Record 26 of Set 1 | uige
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | homer
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | lasa
# Processing Record 33 of Set 1 | coihaique
# Processing Record 34 of Set 1 | qaqortoq
# Processing Record 35 of Set 1 | comayagua
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | agadir
# Processing Record 38 of Set 1 | dunedin
# Processing Record 39 of Set 1 | fort frances
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | kysyl-syr
# Processing Record 43 of Set 1 | korla
# Processing Record 44 of Set 1 | teknaf
# Processing Record 45 of Set 1 | attawapiskat
# City not found, move on to the next...
# Processing Record 46 of Set 1 | avera
# Processing Record 47 of Set 1 | russell
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | namatanai
# Processing Record 50 of Set 1 | luganville
# Processing Record 0 of Set 2 | port elizabeth
# Processing Record 1 of Set 2 | nelson bay
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | tecoh
# Processing Record 4 of Set 2 | aybak
# City not found, move on to the next...
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | porto torres
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | kalianget
# Processing Record 13 of Set 2 | santa isabel do rio negro
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | aflu
# City not found, move on to the next...
# Processing Record 17 of Set 2 | gamba
# Processing Record 18 of Set 2 | agadez
# Processing Record 19 of Set 2 | opuwo
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | novo aripuana
# Processing Record 22 of Set 2 | tessalit
# Processing Record 23 of Set 2 | hambantota
# Processing Record 24 of Set 2 | lieksa
# Processing Record 25 of Set 2 | inuvik
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | prince albert
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | omboue
# Processing Record 31 of Set 2 | wenchi
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | ajdabiya
# Processing Record 34 of Set 2 | arrecife
# Processing Record 35 of Set 2 | belushya guba
# City not found, move on to the next...
# Processing Record 36 of Set 2 | nam tha
# City not found, move on to the next...
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | coquimbo
# Processing Record 39 of Set 2 | strezhevoy
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | taihe
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | plainview
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | kodinsk
# Processing Record 46 of Set 2 | knysna
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | chervone
# Processing Record 49 of Set 2 | sinnai
# Processing Record 0 of Set 3 | mumford
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | russellville
# Processing Record 5 of Set 3 | debre tabor
# Processing Record 6 of Set 3 | road town
# Processing Record 7 of Set 3 | port moresby
# Processing Record 8 of Set 3 | beringovskiy
# Processing Record 9 of Set 3 | taolanaro
# City not found, move on to the next...
# Processing Record 10 of Set 3 | siavonga
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found, move on to the next...
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | palmerston
# Processing Record 14 of Set 3 | bolshoye murashkino
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | bani
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | santa marta
# Processing Record 19 of Set 3 | amderma
# City not found, move on to the next...
# Processing Record 20 of Set 3 | delvada
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | halifax
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | saint-pierre
# Processing Record 25 of Set 3 | carnarvon
# Processing Record 26 of Set 3 | mincivan
# Processing Record 27 of Set 3 | barentsburg
# City not found, move on to the next...
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | sernur
# Processing Record 30 of Set 3 | nabire
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | deming
# Processing Record 33 of Set 3 | tasbuget
# City not found, move on to the next...
# Processing Record 34 of Set 3 | daru
# Processing Record 35 of Set 3 | palmer
# Processing Record 36 of Set 3 | yellowknife
# Processing Record 37 of Set 3 | cervo
# Processing Record 38 of Set 3 | chimoio
# Processing Record 39 of Set 3 | katobu
# Processing Record 40 of Set 3 | balabac
# Processing Record 41 of Set 3 | ahipara
# Processing Record 42 of Set 3 | tuy hoa
# Processing Record 43 of Set 3 | comodoro rivadavia
# Processing Record 44 of Set 3 | ballymena
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | clyde river
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | eau claire
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 0 of Set 4 | vaini
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | salisbury
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | ngukurr
# City not found, move on to the next...
# Processing Record 6 of Set 4 | shatrovo
# Processing Record 7 of Set 4 | eydhafushi
# Processing Record 8 of Set 4 | nanakuli
# Processing Record 9 of Set 4 | solnechnyy
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | hiji
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | jiroft
# City not found, move on to the next...
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | pauini
# Processing Record 16 of Set 4 | majene
# Processing Record 17 of Set 4 | joensuu
# Processing Record 18 of Set 4 | avarua
# Processing Record 19 of Set 4 | el higo
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | jacareacanga
# Processing Record 24 of Set 4 | san policarpo
# Processing Record 25 of Set 4 | yaan
# Processing Record 26 of Set 4 | tual
# Processing Record 27 of Set 4 | illoqqortoormiut
# City not found, move on to the next...
# Processing Record 28 of Set 4 | baruun-urt
# Processing Record 29 of Set 4 | biltine
# Processing Record 30 of Set 4 | ayagoz
# Processing Record 31 of Set 4 | kankavli
# City not found, move on to the next...
# Processing Record 32 of Set 4 | vung tau
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | mys shmidta
# City not found, move on to the next...
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | belmonte
# Processing Record 37 of Set 4 | mudyuga
# City not found, move on to the next...
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | lingao
# Processing Record 40 of Set 4 | tabuleiro do norte
# Processing Record 41 of Set 4 | abilene
# Processing Record 42 of Set 4 | tuyen quang
# Processing Record 43 of Set 4 | tlacotepec
# Processing Record 44 of Set 4 | westport
# Processing Record 45 of Set 4 | baiao
# Processing Record 46 of Set 4 | sinnamary
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | riyadh
# Processing Record 49 of Set 4 | orsha
# Processing Record 0 of Set 5 | cookeville
# Processing Record 1 of Set 5 | chuy
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | paita
# Processing Record 4 of Set 5 | cayenne
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | severo-kurilsk
# Processing Record 7 of Set 5 | abashiri
# Processing Record 8 of Set 5 | taltal
# Processing Record 9 of Set 5 | hofn
# Processing Record 10 of Set 5 | necochea
# Processing Record 11 of Set 5 | bara
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | eston
# Processing Record 14 of Set 5 | krasnyy chikoy
# Processing Record 15 of Set 5 | udachnyy
# Processing Record 16 of Set 5 | urdzhar
# City not found, move on to the next...
# Processing Record 17 of Set 5 | maridi
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | buala
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | scalea
# Processing Record 22 of Set 5 | mogadishu
# Processing Record 23 of Set 5 | yar-sale
# Processing Record 24 of Set 5 | ola
# Processing Record 25 of Set 5 | mamallapuram
# Processing Record 26 of Set 5 | idlib
# Processing Record 27 of Set 5 | saint-augustin
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | belen
# Processing Record 31 of Set 5 | coracao de jesus
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | armacao dos buzios
# City not found, move on to the next...
# Processing Record 34 of Set 5 | contramaestre
# Processing Record 35 of Set 5 | kamenka
# Processing Record 36 of Set 5 | kuche
# City not found, move on to the next...
# Processing Record 37 of Set 5 | mount isa
# Processing Record 38 of Set 5 | beian
# Processing Record 39 of Set 5 | sosva
# Processing Record 40 of Set 5 | pueblo nuevo
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | hovd
# Processing Record 44 of Set 5 | huancavelica
# Processing Record 45 of Set 5 | mukhen
# Processing Record 46 of Set 5 | rossland
# Processing Record 47 of Set 5 | ust-barguzin
# Processing Record 48 of Set 5 | tilichiki
# Processing Record 49 of Set 5 | college
# Processing Record 0 of Set 6 | brumadinho
# Processing Record 1 of Set 6 | zemaiciu naumiestis
# Processing Record 2 of Set 6 | kendari
# Processing Record 3 of Set 6 | iralaya
# Processing Record 4 of Set 6 | cherskiy
# Processing Record 5 of Set 6 | chiredzi
# Processing Record 6 of Set 6 | axim
# Processing Record 7 of Set 6 | jalu
# Processing Record 8 of Set 6 | kulhudhuffushi
# Processing Record 9 of Set 6 | grand gaube
# Processing Record 10 of Set 6 | okha
# Processing Record 11 of Set 6 | astipalaia
# City not found, move on to the next...
# Processing Record 12 of Set 6 | ternate
# Processing Record 13 of Set 6 | andenes
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | souillac
# Processing Record 16 of Set 6 | gizo
# Processing Record 17 of Set 6 | cockburn town
# Processing Record 18 of Set 6 | flinders
# Processing Record 19 of Set 6 | lanxi
# Processing Record 20 of Set 6 | francisco sa
# Processing Record 21 of Set 6 | novyy urengoy
# Processing Record 22 of Set 6 | sorland
# Processing Record 23 of Set 6 | baculin
# Processing Record 24 of Set 6 | honningsvag
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | shaturtorf
# Processing Record 27 of Set 6 | port blair
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | bengkulu
# Processing Record 30 of Set 6 | ucluelet
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | zalantun
# Processing Record 33 of Set 6 | reyes
# Processing Record 34 of Set 6 | poya
# Processing Record 35 of Set 6 | umzimvubu
# City not found, move on to the next...
# Processing Record 36 of Set 6 | gogrial
# Processing Record 37 of Set 6 | rohatyn
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | mancio lima
# Processing Record 40 of Set 6 | naryan-mar
# Processing Record 41 of Set 6 | manzil salim
# Processing Record 42 of Set 6 | rio grande
# Processing Record 43 of Set 6 | rio rancho
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | geraldton
# Processing Record 46 of Set 6 | gat
# Processing Record 47 of Set 6 | barrow
# Processing Record 48 of Set 6 | kamennomostskiy
# Processing Record 49 of Set 6 | carauari
# Processing Record 0 of Set 7 | dicabisagan
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | rancho palos verdes
# Processing Record 3 of Set 7 | tezu
# Processing Record 4 of Set 7 | grand river south east
# City not found, move on to the next...
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | tatarskaya kargala
# Processing Record 7 of Set 7 | lebyazhye
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | camacha
# Processing Record 10 of Set 7 | colares
# Processing Record 11 of Set 7 | vila
# Processing Record 12 of Set 7 | tarko-sale
# Processing Record 13 of Set 7 | barmer
# Processing Record 14 of Set 7 | roros
# Processing Record 15 of Set 7 | garissa
# Processing Record 16 of Set 7 | hihifo
# City not found, move on to the next...
# Processing Record 17 of Set 7 | maceio
# Processing Record 18 of Set 7 | saint-philippe
# Processing Record 19 of Set 7 | tumannyy
# City not found, move on to the next...
# Processing Record 20 of Set 7 | tecoanapa
# Processing Record 21 of Set 7 | dzhalil
# Processing Record 22 of Set 7 | qasigiannguit
# Processing Record 23 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 7 | marinette
# Processing Record 25 of Set 7 | sukhobezvodnoye
# Processing Record 26 of Set 7 | umm kaddadah
# Processing Record 27 of Set 7 | felidhoo
# City not found, move on to the next...
# Processing Record 28 of Set 7 | pemberton
# Processing Record 29 of Set 7 | meadow lake
# Processing Record 30 of Set 7 | deputatskiy
# Processing Record 31 of Set 7 | nizhneyansk
# City not found, move on to the next...
# Processing Record 32 of Set 7 | anqing
# Processing Record 33 of Set 7 | dehloran
# Processing Record 34 of Set 7 | vestmannaeyjar
# Processing Record 35 of Set 7 | qaanaaq
# Processing Record 36 of Set 7 | binga
# Processing Record 37 of Set 7 | marsaxlokk
# Processing Record 38 of Set 7 | leeton
# Processing Record 39 of Set 7 | jiujiang
# Processing Record 40 of Set 7 | shingu
# Processing Record 41 of Set 7 | kavaratti
# Processing Record 42 of Set 7 | novoagansk
# Processing Record 43 of Set 7 | levelland
# Processing Record 44 of Set 7 | bilma
# Processing Record 45 of Set 7 | petrolandia
# City not found, move on to the next...
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | valparaiso
# Processing Record 48 of Set 7 | talen
# Processing Record 49 of Set 7 | arrifes
# Processing Record 0 of Set 8 | yenagoa
# Processing Record 1 of Set 8 | dolbeau
# City not found, move on to the next...
# Processing Record 2 of Set 8 | vao
# Processing Record 3 of Set 8 | hluti
# Processing Record 4 of Set 8 | fort nelson
# Processing Record 5 of Set 8 | richards bay
# Processing Record 6 of Set 8 | viligili
# City not found, move on to the next...
# Processing Record 7 of Set 8 | castro
# Processing Record 8 of Set 8 | nemuro
# Processing Record 9 of Set 8 | chagda
# City not found, move on to the next...
# Processing Record 10 of Set 8 | manggar
# Processing Record 11 of Set 8 | vega de alatorre
# Processing Record 12 of Set 8 | cavalcante
# Processing Record 13 of Set 8 | luwuk
# Processing Record 14 of Set 8 | meulaboh
# Processing Record 15 of Set 8 | amapa
# Processing Record 16 of Set 8 | iranshahr
# Processing Record 17 of Set 8 | strai
# Processing Record 18 of Set 8 | chumphon
# Processing Record 19 of Set 8 | palabuhanratu
# City not found, move on to the next...
# Processing Record 20 of Set 8 | tiarei
# Processing Record 21 of Set 8 | dhar
# Processing Record 22 of Set 8 | vila franca do campo
# Processing Record 23 of Set 8 | pierre
# Processing Record 24 of Set 8 | tabiauea
# City not found, move on to the next...
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | labutta
# City not found, move on to the next...
# Processing Record 27 of Set 8 | sao felix do xingu
# Processing Record 28 of Set 8 | mandal
# Processing Record 29 of Set 8 | gomel
# Processing Record 30 of Set 8 | cabedelo
# Processing Record 31 of Set 8 | cucer
# City not found, move on to the next...
# Processing Record 32 of Set 8 | ambajogai
# Processing Record 33 of Set 8 | los andes
# Processing Record 34 of Set 8 | quatre cocos
# Processing Record 35 of Set 8 | kambove
# Processing Record 36 of Set 8 | east london
# Processing Record 37 of Set 8 | te anau
# Processing Record 38 of Set 8 | nyaunglebin
# Processing Record 39 of Set 8 | buarcos
# Processing Record 40 of Set 8 | cortes
# Processing Record 41 of Set 8 | nova role
# Processing Record 42 of Set 8 | tuatapere
# Processing Record 43 of Set 8 | okhotsk
# Processing Record 44 of Set 8 | port hardy
# Processing Record 45 of Set 8 | nyurba
# Processing Record 46 of Set 8 | gori
# Processing Record 47 of Set 8 | ahuimanu
# Processing Record 48 of Set 8 | salina
# Processing Record 49 of Set 8 | mchinji
# Processing Record 0 of Set 9 | kaitangata
# Processing Record 1 of Set 9 | kifri
# Processing Record 2 of Set 9 | kenitra
# Processing Record 3 of Set 9 | zenzeli
# Processing Record 4 of Set 9 | gazli
# Processing Record 5 of Set 9 | los llanos de aridane
# Processing Record 6 of Set 9 | esso
# Processing Record 7 of Set 9 | melioratorov
# Processing Record 8 of Set 9 | baglung
# Processing Record 9 of Set 9 | anloga
# Processing Record 10 of Set 9 | krasnogorsk
# Processing Record 11 of Set 9 | wuchang
# Processing Record 12 of Set 9 | havoysund
# Processing Record 13 of Set 9 | ilulissat
# Processing Record 14 of Set 9 | stryn
# Processing Record 15 of Set 9 | gimli
# Processing Record 16 of Set 9 | grenfell
# Processing Record 17 of Set 9 | tucuma
# Processing Record 18 of Set 9 | mandan
# Processing Record 19 of Set 9 | casablanca
# Processing Record 20 of Set 9 | tiksi
# Processing Record 21 of Set 9 | srednekolymsk
# Processing Record 22 of Set 9 | praia da vitoria
# Processing Record 23 of Set 9 | pacifica
# Processing Record 24 of Set 9 | mayumba
# Processing Record 25 of Set 9 | suratgarh
# Processing Record 26 of Set 9 | sitia
# Processing Record 27 of Set 9 | fare
# Processing Record 28 of Set 9 | sheopur
# Processing Record 29 of Set 9 | porto seguro
# Processing Record 30 of Set 9 | kahului
# Processing Record 31 of Set 9 | kemi
# Processing Record 32 of Set 9 | waipawa
# Processing Record 33 of Set 9 | aksu
# Processing Record 34 of Set 9 | dera bugti
# Processing Record 35 of Set 9 | hargeysa
# Processing Record 36 of Set 9 | eirunepe
# Processing Record 37 of Set 9 | baykit
# Processing Record 38 of Set 9 | horsham
# Processing Record 39 of Set 9 | condado
# Processing Record 40 of Set 9 | ginda
# Processing Record 41 of Set 9 | tjome
# Processing Record 42 of Set 9 | vaitupu
# City not found, move on to the next...
# Processing Record 43 of Set 9 | marcona
# City not found, move on to the next...
# Processing Record 44 of Set 9 | lamu
# Processing Record 45 of Set 9 | visavadar
# Processing Record 46 of Set 9 | zyryanka
# Processing Record 47 of Set 9 | sabang
# Processing Record 48 of Set 9 | villa rica
# Processing Record 49 of Set 9 | arlit
# Processing Record 0 of Set 10 | canakkale
# Processing Record 1 of Set 10 | saskylakh
# Processing Record 2 of Set 10 | vilhena
# Processing Record 3 of Set 10 | grenada
# Processing Record 4 of Set 10 | nizhniy kuranakh
# Processing Record 5 of Set 10 | bentonville
# Processing Record 6 of Set 10 | bireun
# Processing Record 7 of Set 10 | margate
# Processing Record 8 of Set 10 | isangel
# Processing Record 9 of Set 10 | ziro
# Processing Record 10 of Set 10 | baijiantan
# Processing Record 11 of Set 10 | tocopilla
# Processing Record 12 of Set 10 | noumea
# Processing Record 13 of Set 10 | samarai
# Processing Record 14 of Set 10 | marzuq
# Processing Record 15 of Set 10 | balkanabat
# Processing Record 16 of Set 10 | west wendover
# Processing Record 17 of Set 10 | northam
# Processing Record 18 of Set 10 | manicore
# Processing Record 19 of Set 10 | kenai
# Processing Record 20 of Set 10 | nishihara
# Processing Record 21 of Set 10 | volchansk
# Processing Record 22 of Set 10 | walvis bay
# Processing Record 23 of Set 10 | samusu
# City not found, move on to the next...
# Processing Record 24 of Set 10 | rungata
# City not found, move on to the next...
# Processing Record 25 of Set 10 | oriximina
# Processing Record 26 of Set 10 | tabas
# Processing Record 27 of Set 10 | winnemucca
# Processing Record 28 of Set 10 | lorengau
# Processing Record 29 of Set 10 | baie-comeau
# Processing Record 30 of Set 10 | carlos chagas
# Processing Record 31 of Set 10 | brae
# Processing Record 32 of Set 10 | suntar
# Processing Record 33 of Set 10 | batagay-alyta
# Processing Record 34 of Set 10 | san pedro
# Processing Record 35 of Set 10 | padang
# Processing Record 36 of Set 10 | belyy yar
# Processing Record 37 of Set 10 | muros
# Processing Record 38 of Set 10 | zhigansk
# Processing Record 39 of Set 10 | chicama
# Processing Record 40 of Set 10 | taft
# Processing Record 41 of Set 10 | san roque
# Processing Record 42 of Set 10 | broome
# Processing Record 43 of Set 10 | hope
# Processing Record 44 of Set 10 | olinda
# Processing Record 45 of Set 10 | safwah
# City not found, move on to the next...
# Processing Record 46 of Set 10 | wigston
# Processing Record 47 of Set 10 | collie
# Processing Record 48 of Set 10 | vanimo
# Processing Record 49 of Set 10 | vyartsilya
# Processing Record 0 of Set 11 | matamoros
# Processing Record 1 of Set 11 | ventspils
# Processing Record 2 of Set 11 | cazaje
# City not found, move on to the next...
# Processing Record 3 of Set 11 | kavieng
# Processing Record 4 of Set 11 | zhezkazgan
# Processing Record 5 of Set 11 | carnot
# Processing Record 6 of Set 11 | cheuskiny
# City not found, move on to the next...
# Processing Record 7 of Set 11 | ahumada
# City not found, move on to the next...
# Processing Record 8 of Set 11 | boralday
# Processing Record 9 of Set 11 | pangody
# Processing Record 10 of Set 11 | charlestown
# Processing Record 11 of Set 11 | saint-francois
# Processing Record 12 of Set 11 | cidreira
# Processing Record 13 of Set 11 | san cristobal
# Processing Record 14 of Set 11 | tidore
# City not found, move on to the next...
# Processing Record 15 of Set 11 | bend
# Processing Record 16 of Set 11 | kawalu
# Processing Record 17 of Set 11 | codrington
# Processing Record 18 of Set 11 | namibe
# Processing Record 19 of Set 11 | tucumcari
# Processing Record 20 of Set 11 | aksarka
# Processing Record 21 of Set 11 | ponta delgada
# Processing Record 22 of Set 11 | kolosovka
# Processing Record 23 of Set 11 | yarada
# Processing Record 24 of Set 11 | lagoa
# Processing Record 25 of Set 11 | sataua
# City not found, move on to the next...
# Processing Record 26 of Set 11 | le port
# Processing Record 27 of Set 11 | kaeo
# Processing Record 28 of Set 11 | grazhdanskoye pervoye
# City not found, move on to the next...
# Processing Record 29 of Set 11 | campoverde
# Processing Record 30 of Set 11 | enshi
# Processing Record 31 of Set 11 | menongue
# Processing Record 32 of Set 11 | alofi
# Processing Record 33 of Set 11 | tefe
# Processing Record 34 of Set 11 | yumen
# Processing Record 35 of Set 11 | kayunga
# Processing Record 36 of Set 11 | setermoen
# Processing Record 37 of Set 11 | shu
# Processing Record 38 of Set 11 | bose
# Processing Record 39 of Set 11 | burica
# City not found, move on to the next...
# Processing Record 40 of Set 11 | catalina foothills
# Processing Record 41 of Set 11 | warqla
# City not found, move on to the next...
# Processing Record 42 of Set 11 | nchelenge
# Processing Record 43 of Set 11 | esmeraldas
# Processing Record 44 of Set 11 | champerico
# Processing Record 45 of Set 11 | trincomalee
# Processing Record 46 of Set 11 | chirongui
# Processing Record 47 of Set 11 | kaspiyskiy
# Processing Record 48 of Set 11 | chara
# Processing Record 49 of Set 11 | la asuncion
# Processing Record 0 of Set 12 | erenhot
# Processing Record 1 of Set 12 | babati
# Processing Record 2 of Set 12 | saleaula
# City not found, move on to the next...
# Processing Record 3 of Set 12 | qandahar
# City not found, move on to the next...
# Processing Record 4 of Set 12 | cheyenne
# Processing Record 5 of Set 12 | kismayo
# Processing Record 6 of Set 12 | bow island
# Processing Record 7 of Set 12 | bandarbeyla
# Processing Record 8 of Set 12 | pangai
# Processing Record 9 of Set 12 | moron
# Processing Record 10 of Set 12 | port-gentil
# Processing Record 11 of Set 12 | tsaratanana
# Processing Record 12 of Set 12 | tornio
# Processing Record 13 of Set 12 | dali
# Processing Record 14 of Set 12 | henties bay
# Processing Record 15 of Set 12 | gambissara
# Processing Record 16 of Set 12 | gore
# Processing Record 17 of Set 12 | zapolyarnyy
# Processing Record 18 of Set 12 | newport
# Processing Record 19 of Set 12 | kananga
# Processing Record 20 of Set 12 | hualmay
# Processing Record 21 of Set 12 | chuncheng
# Processing Record 22 of Set 12 | la quinta
# Processing Record 23 of Set 12 | la rioja
# Processing Record 24 of Set 12 | karratha
# Processing Record 25 of Set 12 | tautira
# Processing Record 26 of Set 12 | luba
# Processing Record 27 of Set 12 | jutai
# Processing Record 28 of Set 12 | murmino
# Processing Record 29 of Set 12 | paarl
# Processing Record 30 of Set 12 | charkhari
# Processing Record 31 of Set 12 | kudahuvadhoo
# Processing Record 32 of Set 12 | saint anthony
# Processing Record 33 of Set 12 | ust-tsilma
# Processing Record 34 of Set 12 | urucara
# Processing Record 35 of Set 12 | maxixe
# Processing Record 36 of Set 12 | kentau
# Processing Record 37 of Set 12 | kontagora
# Processing Record 38 of Set 12 | duku
# Processing Record 39 of Set 12 | barcelos
# Processing Record 40 of Set 12 | camopi
# Processing Record 41 of Set 12 | kungurtug
# Processing Record 42 of Set 12 | bambanglipuro
# Processing Record 43 of Set 12 | enumclaw
# Processing Record 44 of Set 12 | ulaangom
# Processing Record 45 of Set 12 | batemans bay
# Processing Record 46 of Set 12 | bima
# Processing Record 47 of Set 12 | kamenskoye
# City not found, move on to the next...
# Processing Record 48 of Set 12 | bonthe
# Processing Record 49 of Set 12 | terre-de-bas
# Processing Record 0 of Set 13 | chadan
# Processing Record 1 of Set 13 | scarborough
# Processing Record 2 of Set 13 | susanville
# Processing Record 3 of Set 13 | sovetskaya gavan
# Processing Record 4 of Set 13 | sarlat-la-caneda
# Processing Record 5 of Set 13 | banda aceh
# Processing Record 6 of Set 13 | genc
# Processing Record 7 of Set 13 | sandwick
# Processing Record 8 of Set 13 | sao francisco de assis
# Processing Record 9 of Set 13 | atambua
# Processing Record 10 of Set 13 | tondano
# Processing Record 11 of Set 13 | gaziantep
# Processing Record 12 of Set 13 | karaul
# City not found, move on to the next...
# Processing Record 13 of Set 13 | louisbourg
# City not found, move on to the next...
# Processing Record 14 of Set 13 | taoudenni
# Processing Record 15 of Set 13 | acandi
# Processing Record 16 of Set 13 | zaraza
# Processing Record 17 of Set 13 | okoneshnikovo
# Processing Record 18 of Set 13 | cap malheureux
# Processing Record 19 of Set 13 | kargasok
# Processing Record 20 of Set 13 | kalmunai
# Processing Record 21 of Set 13 | pacific grove
# Processing Record 22 of Set 13 | joshimath
# Processing Record 23 of Set 13 | ovsyanka
# Processing Record 24 of Set 13 | toliary
# City not found, move on to the next...
# Processing Record 25 of Set 13 | dabola
# Processing Record 26 of Set 13 | vila velha
# Processing Record 27 of Set 13 | kyra
# Processing Record 28 of Set 13 | waingapu
# -------------------
# Data Retrieval Complete
# --------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           oksbol  55.63    8.29     48.99        87           0        9.17
# 1       chokurdakh  70.63  147.92    -14.19        84           0        5.84
# 2      grahamstown -33.30   26.53     60.89        93         100        9.86
# 3    mount gambier -37.83  140.77     46.40        81          40        8.05
# 4             asau  46.43   26.40     36.00        97           0        1.39
# ..             ...    ...     ...       ...       ...         ...         ...
# 569       ovsyanka  55.96   92.55     26.60        86          75       11.18
# 570         dabola  10.75  -11.12     79.12        59           0        2.44
# 571     vila velha -20.33  -40.29     73.40        78          90        5.82
# 572           kyra  49.58  111.98     24.55        91         100        1.77
# 573       waingapu  -9.66  120.26     80.46        75          35        2.86
#
#     Country        Date
# 0        DK  1604514658
# 1        RU  1604514658
# 2        ZA  1604514658
# 3        AU  1604514658
# 4        RO  1604514658
# ..      ...         ...
# 569      RU  1604514749
# 570      GN  1604514749
# 571      BR  1604514750
# 572      RU  1604514750
# 573      ID  1604514750
#
# [574 rows x 9 columns]

# %%
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
city_data_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           oksbol  55.63    8.29     48.99        87           0        9.17
# 1       chokurdakh  70.63  147.92    -14.19        84           0        5.84
# 2      grahamstown -33.30   26.53     60.89        93         100        9.86
# 3    mount gambier -37.83  140.77     46.40        81          40        8.05
# 4             asau  46.43   26.40     36.00        97           0        1.39
# ..             ...    ...     ...       ...       ...         ...         ...
# 569       ovsyanka  55.96   92.55     26.60        86          75       11.18
# 570         dabola  10.75  -11.12     79.12        59           0        2.44
# 571     vila velha -20.33  -40.29     73.40        78          90        5.82
# 572           kyra  49.58  111.98     24.55        91         100        1.77
# 573       waingapu  -9.66  120.26     80.46        75          35        2.86
#
#     Country        Date
# 0        DK  1604514658
# 1        RU  1604514658
# 2        ZA  1604514658
# 3        AU  1604514658
# 4        RO  1604514658
# ..      ...         ...
# 569      RU  1604514749
# 570      GN  1604514749
# 571      BR  1604514750
# 572      RU  1604514750
# 573      ID  1604514750
#
# [574 rows x 9 columns]

# %%
city_data
# Out:
# [{'City': 'oksbol',
#   'Lat': 55.63,
#   'Lng': 8.29,
#   'Max Temp': 48.99,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'DK',
#   'Date': 1604514658},
#  {'City': 'chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -14.19,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 5.84,
#   'Country': 'RU',
#   'Date': 1604514658},
#  {'City': 'grahamstown',
#   'Lat': -33.3,
#   'Lng': 26.53,
#   'Max Temp': 60.89,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.86,
#   'Country': 'ZA',
#   'Date': 1604514658},
#  {'City': 'mount gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': 1604514658},
#  {'City': 'asau',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 36,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 1.39,
#   'Country': 'RO',
#   'Date': 1604514658},
#  {'City': 'bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 4.62,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Date': 1604514658},
#  {'City': 'tobetsu',
#   'Lat': 43.22,
#   'Lng': 141.52,
#   'Max Temp': 39,
#   'Humidity': 89,
#   'Cloudiness': 78,
#   'Wind Speed': 14.18,
#   'Country': 'JP',
#   'Date': 1604514658},
#  {'City': 'pangnirtung',
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Max Temp': 8.6,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Date': 1604514658},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 57,
#   'Humidity': 97,
#   'Cloudiness': 79,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': 1604514659},
#  {'City': 'new norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 45,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': 1604514659},
#  {'City': 'touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Country': 'BR',
#   'Date': 1604514659},
#  {'City': 'maniitsoq',
#   'Lat': 65.42,
#   'Lng': -52.9,
#   'Max Temp': 28.31,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 26.15,
#   'Country': 'GL',
#   'Date': 1604514659},
#  {'City': 'havre-saint-pierre',
#   'Lat': 50.23,
#   'Lng': -63.6,
#   'Max Temp': 28.4,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 18.34,
#   'Country': 'CA',
#   'Date': 1604514659},
#  {'City': 'mehamn',
#   'Lat': 71.04,
#   'Lng': 27.85,
#   'Max Temp': 35.6,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'NO',
#   'Date': 1604514659},
#  {'City': 'albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 57,
#   'Humidity': 44,
#   'Cloudiness': 2,
#   'Wind Speed': 8.5,
#   'Country': 'US',
#   'Date': 1604514430},
#  {'City': 'cape town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 71.6,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 19.46,
#   'Country': 'ZA',
#   'Date': 1604514572},
#  {'City': 'wodonga',
#   'Lat': -36.12,
#   'Lng': 146.88,
#   'Max Temp': 55.4,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Date': 1604514419},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 52,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Date': 1604514659},
#  {'City': 'terme',
#   'Lat': 41.21,
#   'Lng': 36.97,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'TR',
#   'Date': 1604514659},
#  {'City': 'salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'OM',
#   'Date': 1604514660},
#  {'City': 'lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 55.8,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 9.51,
#   'Country': 'CL',
#   'Date': 1604514660},
#  {'City': 'ust-nera',
#   'Lat': 64.57,
#   'Lng': 143.2,
#   'Max Temp': 1.02,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.2,
#   'Country': 'RU',
#   'Date': 1604514660},
#  {'City': 'aswan',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 71.19,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'EG',
#   'Date': 1604514660},
#  {'City': 'uige',
#   'Lat': -7.61,
#   'Lng': 15.06,
#   'Max Temp': 70.21,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.92,
#   'Country': 'AO',
#   'Date': 1604514660},
#  {'City': 'sao joao da barra',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 77,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Country': 'BR',
#   'Date': 1604514660},
#  {'City': 'dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 1.47,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Country': 'RU',
#   'Date': 1604514660},
#  {'City': 'homer',
#   'Lat': 59.64,
#   'Lng': -151.55,
#   'Max Temp': 21,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1604514661},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 62.6,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'AR',
#   'Date': 1604514661},
#  {'City': 'butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 80.58,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 12.39,
#   'Country': 'KI',
#   'Date': 1604514661},
#  {'City': 'lasa',
#   'Lat': 46.62,
#   'Lng': 10.7,
#   'Max Temp': 53.01,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'IT',
#   'Date': 1604514661},
#  {'City': 'coihaique',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 53.6,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'CL',
#   'Date': 1604514661},
#  {'City': 'qaqortoq',
#   'Lat': 60.72,
#   'Lng': -46.03,
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'GL',
#   'Date': 1604514661},
#  {'City': 'comayagua',
#   'Lat': 14.45,
#   'Lng': -87.63,
#   'Max Temp': 68,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'HN',
#   'Date': 1604514662},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'CL',
#   'Date': 1604514495},
#  {'City': 'agadir',
#   'Lat': 30.42,
#   'Lng': -9.6,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'MA',
#   'Date': 1604514565},
#  {'City': 'dunedin',
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 60.89,
#   'Humidity': 72,
#   'Cloudiness': 85,
#   'Wind Speed': 4.94,
#   'Country': 'NZ',
#   'Date': 1604514662},
#  {'City': 'fort frances',
#   'Lat': 48.6,
#   'Lng': -93.4,
#   'Max Temp': 62.6,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'CA',
#   'Date': 1604514662},
#  {'City': 'nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': 1604514662},
#  {'City': 'puerto ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'EC',
#   'Date': 1604514662},
#  {'City': 'kysyl-syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': 0.88,
#   'Humidity': 93,
#   'Cloudiness': 88,
#   'Wind Speed': 4.72,
#   'Country': 'RU',
#   'Date': 1604514662},
#  {'City': 'korla',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 42.28,
#   'Humidity': 53,
#   'Cloudiness': 4,
#   'Wind Speed': 8.75,
#   'Country': 'CN',
#   'Date': 1604514663},
#  {'City': 'teknaf',
#   'Lat': 20.86,
#   'Lng': 92.31,
#   'Max Temp': 76.75,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Country': 'BD',
#   'Date': 1604514663},
#  {'City': 'avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 69.8,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': 1604514663},
#  {'City': 'russell',
#   'Lat': 32.35,
#   'Lng': -85.2,
#   'Max Temp': 71.6,
#   'Humidity': 33,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1604514603},
#  {'City': 'mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 57,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': 1604514663},
#  {'City': 'namatanai',
#   'Lat': -3.67,
#   'Lng': 152.43,
#   'Max Temp': 80.65,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 7.27,
#   'Country': 'PG',
#   'Date': 1604514663},
#  {'City': 'luganville',
#   'Lat': -15.53,
#   'Lng': 167.17,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.38,
#   'Country': 'VU',
#   'Date': 1604514663},
#  {'City': 'port elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'ZA',
#   'Date': 1604514663},
#  {'City': 'nelson bay',
#   'Lat': -32.72,
#   'Lng': 152.15,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'AU',
#   'Date': 1604514663},
#  {'City': 'caravelas',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 72.36,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Country': 'BR',
#   'Date': 1604514664},
#  {'City': 'tecoh',
#   'Lat': 20.75,
#   'Lng': -89.47,
#   'Max Temp': 84,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'MX',
#   'Date': 1604514664},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.75,
#   'Humidity': 77,
#   'Cloudiness': 14,
#   'Wind Speed': 21.52,
#   'Country': 'PF',
#   'Date': 1604514664},
#  {'City': 'porto torres',
#   'Lat': 40.84,
#   'Lng': 8.4,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'IT',
#   'Date': 1604514664},
#  {'City': 'khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': -5.98,
#   'Humidity': 91,
#   'Cloudiness': 18,
#   'Wind Speed': 8.46,
#   'Country': 'RU',
#   'Date': 1604514664},
#  {'City': 'port alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 68.7,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 10.13,
#   'Country': 'ZA',
#   'Date': 1604514581},
#  {'City': 'pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 2.28,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 3.24,
#   'Country': 'RU',
#   'Date': 1604514629},
#  {'City': 'jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 62.6,
#   'Humidity': 39,
#   'Cloudiness': 1,
#   'Wind Speed': 14.99,
#   'Country': 'US',
#   'Date': 1604514664},
#  {'City': 'grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 32.21,
#   'Country': 'IS',
#   'Date': 1604514665},
#  {'City': 'kalianget',
#   'Lat': -7.05,
#   'Lng': 113.93,
#   'Max Temp': 83.23,
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 10.45,
#   'Country': 'ID',
#   'Date': 1604514665},
#  {'City': 'santa isabel do rio negro',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 86.45,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Country': 'BR',
#   'Date': 1604514665},
#  {'City': 'kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 69.01,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'ZA',
#   'Date': 1604514665},
#  {'City': 'rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.36,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'PF',
#   'Date': 1604514665},
#  {'City': 'gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 76.64,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Country': 'GA',
#   'Date': 1604514665},
#  {'City': 'agadez',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 73.38,
#   'Humidity': 24,
#   'Cloudiness': 60,
#   'Wind Speed': 6.13,
#   'Country': 'NE',
#   'Date': 1604514665},
#  {'City': 'opuwo',
#   'Lat': -18.06,
#   'Lng': 13.84,
#   'Max Temp': 73.33,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 10.45,
#   'Country': 'NA',
#   'Date': 1604514665},
#  {'City': 'bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 42,
#   'Wind Speed': 10.29,
#   'Country': 'ZA',
#   'Date': 1604514665},
#  {'City': 'novo aripuana',
#   'Lat': -5.12,
#   'Lng': -60.38,
#   'Max Temp': 90.05,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'BR',
#   'Date': 1604514666},
#  {'City': 'tessalit',
#   'Lat': 20.2,
#   'Lng': 1.01,
#   'Max Temp': 78.37,
#   'Humidity': 19,
#   'Cloudiness': 42,
#   'Wind Speed': 5.03,
#   'Country': 'ML',
#   'Date': 1604514666},
#  {'City': 'hambantota',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 79.43,
#   'Humidity': 82,
#   'Cloudiness': 86,
#   'Wind Speed': 2.95,
#   'Country': 'LK',
#   'Date': 1604514666},
#  {'City': 'lieksa',
#   'Lat': 63.32,
#   'Lng': 30.02,
#   'Max Temp': 43.09,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 13.58,
#   'Country': 'FI',
#   'Date': 1604514666},
#  {'City': 'inuvik',
#   'Lat': 68.35,
#   'Lng': -133.72,
#   'Max Temp': 5,
#   'Humidity': 84,
#   'Cloudiness': 61,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': 1604514666},
#  {'City': 'klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 94,
#   'Wind Speed': 24.16,
#   'Country': 'FO',
#   'Date': 1604514666},
#  {'City': 'prince albert',
#   'Lat': 53.2,
#   'Lng': -105.77,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1604514666},
#  {'City': 'bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 61,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': 1604514495},
#  {'City': 'hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1604514656},
#  {'City': 'omboue',
#   'Lat': -1.57,
#   'Lng': 9.26,
#   'Max Temp': 76.1,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.54,
#   'Country': 'GA',
#   'Date': 1604514666},
#  {'City': 'wenchi',
#   'Lat': 7.74,
#   'Lng': -2.1,
#   'Max Temp': 79.79,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 2.46,
#   'Country': 'GH',
#   'Date': 1604514667},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'CA',
#   'Date': 1604514667},
#  {'City': 'ajdabiya',
#   'Lat': 30.76,
#   'Lng': 20.23,
#   'Max Temp': 68.74,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 7.27,
#   'Country': 'LY',
#   'Date': 1604514667},
#  {'City': 'arrecife',
#   'Lat': 28.96,
#   'Lng': -13.55,
#   'Max Temp': 69.8,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'ES',
#   'Date': 1604514667},
#  {'City': 'luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 62.98,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 13.04,
#   'Country': 'NA',
#   'Date': 1604514667},
#  {'City': 'coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Country': 'CL',
#   'Date': 1604514667},
#  {'City': 'strezhevoy',
#   'Lat': 60.73,
#   'Lng': 77.59,
#   'Max Temp': 33.8,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': 1604514667},
#  {'City': 'saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 88,
#   'Wind Speed': 5.82,
#   'Country': 'ZA',
#   'Date': 1604514667},
#  {'City': 'taihe',
#   'Lat': 30.87,
#   'Lng': 105.38,
#   'Max Temp': 58.91,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Country': 'CN',
#   'Date': 1604514667},
#  {'City': 'kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1604514668},
#  {'City': 'plainview',
#   'Lat': 40.78,
#   'Lng': -73.47,
#   'Max Temp': 63,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Date': 1604514636},
#  {'City': 'georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'MY',
#   'Date': 1604514444},
#  {'City': 'kodinsk',
#   'Lat': 58.69,
#   'Lng': 99.18,
#   'Max Temp': 22.91,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.25,
#   'Country': 'RU',
#   'Date': 1604514668},
#  {'City': 'knysna',
#   'Lat': -34.04,
#   'Lng': 23.05,
#   'Max Temp': 64.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'ZA',
#   'Date': 1604514668},
#  {'City': 'provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 30.36,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.68,
#   'Country': 'RU',
#   'Date': 1604514668},
#  {'City': 'chervone',
#   'Lat': 49.96,
#   'Lng': 28.86,
#   'Max Temp': 42.57,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 4.79,
#   'Country': 'UA',
#   'Date': 1604514668},
#  {'City': 'sinnai',
#   'Lat': 39.3,
#   'Lng': 9.2,
#   'Max Temp': 64.99,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'IT',
#   'Date': 1604514669},
#  {'City': 'mumford',
#   'Lat': 5.26,
#   'Lng': -0.76,
#   'Max Temp': 80.38,
#   'Humidity': 82,
#   'Cloudiness': 39,
#   'Wind Speed': 7.72,
#   'Country': 'GH',
#   'Date': 1604514669},
#  {'City': 'upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 17.98,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'GL',
#   'Date': 1604514669},
#  {'City': 'constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 59.92,
#   'Humidity': 58,
#   'Cloudiness': 71,
#   'Wind Speed': 21.94,
#   'Country': 'CL',
#   'Date': 1604514669},
#  {'City': 'hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 46.4,
#   'Humidity': 61,
#   'Cloudiness': 2,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Date': 1604514599},
#  {'City': 'russellville',
#   'Lat': 35.28,
#   'Lng': -93.13,
#   'Max Temp': 72,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': 1604514562},
#  {'City': 'debre tabor',
#   'Lat': 11.85,
#   'Lng': 38.02,
#   'Max Temp': 53.44,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 1.68,
#   'Country': 'ET',
#   'Date': 1604514669},
#  {'City': 'road town',
#   'Lat': 18.42,
#   'Lng': -64.62,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'VG',
#   'Date': 1604514533},
#  {'City': 'port moresby',
#   'Lat': -9.44,
#   'Lng': 147.18,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'PG',
#   'Date': 1604514570},
#  {'City': 'beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 36.28,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 17.13,
#   'Country': 'RU',
#   'Date': 1604514669},
#  {'City': 'siavonga',
#   'Lat': -16.54,
#   'Lng': 28.71,
#   'Max Temp': 82.38,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.55,
#   'Country': 'ZM',
#   'Date': 1604514670},
#  {'City': 'thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 26.6,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': 1604514670},
#  {'City': 'palmerston',
#   'Lat': -12.49,
#   'Lng': 130.98,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'AU',
#   'Date': 1604514670},
#  {'City': 'bolshoye murashkino',
#   'Lat': 55.78,
#   'Lng': 44.78,
#   'Max Temp': 39.61,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Country': 'RU',
#   'Date': 1604514670},
#  {'City': 'ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 84.2,
#   'Humidity': 48,
#   'Cloudiness': 5,
#   'Wind Speed': 6.93,
#   'Country': 'MX',
#   'Date': 1604514670},
#  {'City': 'bani',
#   'Lat': 18.28,
#   'Lng': -70.33,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'DO',
#   'Date': 1604514562},
#  {'City': 'rawson',
#   'Lat': -43.3,
#   'Lng': -65.1,
#   'Max Temp': 76.75,
#   'Humidity': 34,
#   'Cloudiness': 27,
#   'Wind Speed': 25.81,
#   'Country': 'AR',
#   'Date': 1604514671},
#  {'City': 'santa marta',
#   'Lat': 11.24,
#   'Lng': -74.2,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 65,
#   'Wind Speed': 6.31,
#   'Country': 'CO',
#   'Date': 1604514518},
#  {'City': 'delvada',
#   'Lat': 20.77,
#   'Lng': 71.03,
#   'Max Temp': 78.37,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 6.31,
#   'Country': 'IN',
#   'Date': 1604514671},
#  {'City': 'norman wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': -5.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': 1604514671},
#  {'City': 'halifax',
#   'Lat': 44.65,
#   'Lng': -63.57,
#   'Max Temp': 37,
#   'Humidity': 43,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': 1604514650},
#  {'City': 'arraial do cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': 1604514671},
#  {'City': 'saint-pierre',
#   'Lat': -21.34,
#   'Lng': 55.48,
#   'Max Temp': 73.4,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'RE',
#   'Date': 1604514671},
#  {'City': 'carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 17.22,
#   'Country': 'AU',
#   'Date': 1604514671},
#  {'City': 'mincivan',
#   'Lat': 39.03,
#   'Lng': 46.72,
#   'Max Temp': 59.79,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.28,
#   'Country': 'AZ',
#   'Date': 1604514671},
#  {'City': 'airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 61.3,
#   'Humidity': 83,
#   'Cloudiness': 67,
#   'Wind Speed': 2.33,
#   'Country': 'TL',
#   'Date': 1604514672},
#  {'City': 'sernur',
#   'Lat': 56.93,
#   'Lng': 49.15,
#   'Max Temp': 37.89,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Country': 'RU',
#   'Date': 1604514672},
#  {'City': 'nabire',
#   'Lat': -3.37,
#   'Lng': 135.48,
#   'Max Temp': 75.11,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 4.63,
#   'Country': 'ID',
#   'Date': 1604514672},
#  {'City': 'iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 8.6,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': 1604514672},
#  {'City': 'deming',
#   'Lat': 32.27,
#   'Lng': -107.76,
#   'Max Temp': 73.4,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': 1604514672},
#  {'City': 'daru',
#   'Lat': -9.08,
#   'Lng': 143.21,
#   'Max Temp': 78.46,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 10.87,
#   'Country': 'PG',
#   'Date': 1604514672},
#  {'City': 'palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 59,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': 1604514673},
#  {'City': 'yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 0,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': 1604514603},
#  {'City': 'cervo',
#   'Lat': 43.67,
#   'Lng': -7.41,
#   'Max Temp': 48,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Country': 'ES',
#   'Date': 1604514674},
#  {'City': 'chimoio',
#   'Lat': -19.12,
#   'Lng': 33.48,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'MZ',
#   'Date': 1604514674},
#  {'City': 'katobu',
#   'Lat': -4.94,
#   'Lng': 122.53,
#   'Max Temp': 75.72,
#   'Humidity': 91,
#   'Cloudiness': 16,
#   'Wind Speed': 2.51,
#   'Country': 'ID',
#   'Date': 1604514674},
#  {'City': 'balabac',
#   'Lat': 7.99,
#   'Lng': 117.06,
#   'Max Temp': 81.05,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'PH',
#   'Date': 1604514675},
#  {'City': 'ahipara',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 61.57,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 14.25,
#   'Country': 'NZ',
#   'Date': 1604514675},
#  {'City': 'tuy hoa',
#   'Lat': 13.08,
#   'Lng': 109.3,
#   'Max Temp': 72.55,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'VN',
#   'Date': 1604514675},
#  {'City': 'comodoro rivadavia',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 73.4,
#   'Humidity': 25,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Country': 'AR',
#   'Date': 1604514503},
#  {'City': 'ballymena',
#   'Lat': 54.86,
#   'Lng': -6.28,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'GB',
#   'Date': 1604514675},
#  {'City': 'ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 36.27,
#   'Humidity': 84,
#   'Cloudiness': 76,
#   'Wind Speed': 22.82,
#   'Country': 'RU',
#   'Date': 1604514675},
#  {'City': 'clyde river',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 6.8,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'CA',
#   'Date': 1604514471},
#  {'City': 'mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'MU',
#   'Date': 1604514676},
#  {'City': 'eau claire',
#   'Lat': 44.81,
#   'Lng': -91.5,
#   'Max Temp': 68,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': 1604514546},
#  {'City': 'longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 32,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Country': 'SJ',
#   'Date': 1604514676},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'TO',
#   'Date': 1604514676},
#  {'City': 'tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 32,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'GL',
#   'Date': 1604514676},
#  {'City': 'salisbury',
#   'Lat': 51.07,
#   'Lng': -1.8,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'GB',
#   'Date': 1604514478},
#  {'City': 'mar del plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 71.6,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 20.8,
#   'Country': 'AR',
#   'Date': 1604514582},
#  {'City': 'hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 68,
#   'Humidity': 79,
#   'Cloudiness': 27,
#   'Wind Speed': 7,
#   'Country': 'ZA',
#   'Date': 1604514562},
#  {'City': 'shatrovo',
#   'Lat': 56.52,
#   'Lng': 64.63,
#   'Max Temp': 35.28,
#   'Humidity': 86,
#   'Cloudiness': 4,
#   'Wind Speed': 12.59,
#   'Country': 'RU',
#   'Date': 1604514676},
#  {'City': 'eydhafushi',
#   'Lat': 5.1,
#   'Lng': 73.07,
#   'Max Temp': 82.42,
#   'Humidity': 70,
#   'Cloudiness': 63,
#   'Wind Speed': 1.92,
#   'Country': 'MV',
#   'Date': 1604514676},
#  {'City': 'nanakuli',
#   'Lat': 21.39,
#   'Lng': -158.15,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': 1604514676},
#  {'City': 'solnechnyy',
#   'Lat': 50.72,
#   'Lng': 136.63,
#   'Max Temp': 18.66,
#   'Humidity': 84,
#   'Cloudiness': 9,
#   'Wind Speed': 1.3,
#   'Country': 'RU',
#   'Date': 1604514677},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 28.4,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1604514677},
#  {'City': 'hiji',
#   'Lat': 33.37,
#   'Lng': 131.53,
#   'Max Temp': 44.17,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 3.2,
#   'Country': 'JP',
#   'Date': 1604514678},
#  {'City': 'saint george',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 62.6,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1604514605},
#  {'City': 'bambous virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 73,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'MU',
#   'Date': 1604514678},
#  {'City': 'pauini',
#   'Lat': -7.71,
#   'Lng': -66.98,
#   'Max Temp': 99.34,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'BR',
#   'Date': 1604514679},
#  {'City': 'majene',
#   'Lat': -3.54,
#   'Lng': 118.97,
#   'Max Temp': 78.46,
#   'Humidity': 83,
#   'Cloudiness': 15,
#   'Wind Speed': 4.14,
#   'Country': 'ID',
#   'Date': 1604514679},
#  {'City': 'joensuu',
#   'Lat': 62.6,
#   'Lng': 29.76,
#   'Max Temp': 43,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'FI',
#   'Date': 1604514679},
#  {'City': 'avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 24.67,
#   'Country': 'CK',
#   'Date': 1604514679},
#  {'City': 'el higo',
#   'Lat': 21.77,
#   'Lng': -98.47,
#   'Max Temp': 79.81,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 1.9,
#   'Country': 'MX',
#   'Date': 1604514679},
#  {'City': 'san patricio',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 81,
#   'Humidity': 44,
#   'Cloudiness': 40,
#   'Wind Speed': 9.46,
#   'Country': 'US',
#   'Date': 1604514680},
#  {'City': 'vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 37.4,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 35.57,
#   'Country': 'NO',
#   'Date': 1604514680},
#  {'City': 'ribeira grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 60.8,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'PT',
#   'Date': 1604514680},
#  {'City': 'jacareacanga',
#   'Lat': -6.22,
#   'Lng': -57.75,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Date': 1604514680},
#  {'City': 'san policarpo',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 79.59,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Country': 'PH',
#   'Date': 1604514680},
#  {'City': 'yaan',
#   'Lat': 7.38,
#   'Lng': 8.57,
#   'Max Temp': 81.25,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Country': 'NG',
#   'Date': 1604514680},
#  {'City': 'tual',
#   'Lat': -5.67,
#   'Lng': 132.75,
#   'Max Temp': 82.53,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 13.96,
#   'Country': 'ID',
#   'Date': 1604514681},
#  {'City': 'baruun-urt',
#   'Lat': 46.68,
#   'Lng': 113.28,
#   'Max Temp': 21.29,
#   'Humidity': 86,
#   'Cloudiness': 77,
#   'Wind Speed': 2.55,
#   'Country': 'MN',
#   'Date': 1604514681},
#  {'City': 'biltine',
#   'Lat': 14.53,
#   'Lng': 20.92,
#   'Max Temp': 83.32,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 9.33,
#   'Country': 'TD',
#   'Date': 1604514681},
#  {'City': 'ayagoz',
#   'Lat': 47.97,
#   'Lng': 80.44,
#   'Max Temp': 22.91,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'KZ',
#   'Date': 1604514681},
#  {'City': 'vung tau',
#   'Lat': 10.35,
#   'Lng': 107.08,
#   'Max Temp': 78.06,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 8.66,
#   'Country': 'VN',
#   'Date': 1604514682},
#  {'City': 'lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 22.86,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.3,
#   'Country': 'RU',
#   'Date': 1604514682},
#  {'City': 'torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 30,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Country': 'CA',
#   'Date': 1604514682},
#  {'City': 'belmonte',
#   'Lat': -15.86,
#   'Lng': -38.88,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'BR',
#   'Date': 1604514682},
#  {'City': 'fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 68,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 4.21,
#   'Country': 'US',
#   'Date': 1604514683},
#  {'City': 'lingao',
#   'Lat': 19.91,
#   'Lng': 109.69,
#   'Max Temp': 71.78,
#   'Humidity': 83,
#   'Cloudiness': 84,
#   'Wind Speed': 9.48,
#   'Country': 'CN',
#   'Date': 1604514683},
#  {'City': 'tabuleiro do norte',
#   'Lat': -5.25,
#   'Lng': -38.13,
#   'Max Temp': 90.73,
#   'Humidity': 42,
#   'Cloudiness': 95,
#   'Wind Speed': 9.91,
#   'Country': 'BR',
#   'Date': 1604514683},
#  {'City': 'abilene',
#   'Lat': 32.45,
#   'Lng': -99.73,
#   'Max Temp': 73,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 20.8,
#   'Country': 'US',
#   'Date': 1604514683},
#  {'City': 'tuyen quang',
#   'Lat': 21.82,
#   'Lng': 105.22,
#   'Max Temp': 66.97,
#   'Humidity': 76,
#   'Cloudiness': 93,
#   'Wind Speed': 1.57,
#   'Country': 'VN',
#   'Date': 1604514683},
#  {'City': 'tlacotepec',
#   'Lat': 20.07,
#   'Lng': -97.87,
#   'Max Temp': 67.17,
#   'Humidity': 45,
#   'Cloudiness': 44,
#   'Wind Speed': 6.38,
#   'Country': 'MX',
#   'Date': 1604514683},
#  {'City': 'westport',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 62.01,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': 1604514637},
#  {'City': 'baiao',
#   'Lat': -2.79,
#   'Lng': -49.67,
#   'Max Temp': 93.18,
#   'Humidity': 45,
#   'Cloudiness': 33,
#   'Wind Speed': 3.94,
#   'Country': 'BR',
#   'Date': 1604514684},
#  {'City': 'sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 83.66,
#   'Humidity': 72,
#   'Cloudiness': 78,
#   'Wind Speed': 11.54,
#   'Country': 'GF',
#   'Date': 1604514684},
#  {'City': 'nome',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 6.8,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1604514684},
#  {'City': 'riyadh',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 73.4,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'SA',
#   'Date': 1604514617},
#  {'City': 'orsha',
#   'Lat': 54.52,
#   'Lng': 30.41,
#   'Max Temp': 45.09,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Country': 'BY',
#   'Date': 1604514684},
#  {'City': 'cookeville',
#   'Lat': 36.16,
#   'Lng': -85.5,
#   'Max Temp': 68,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1604514409},
#  {'City': 'chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 63.93,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 11.21,
#   'Country': 'UY',
#   'Date': 1604514684},
#  {'City': 'ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 57.99,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'CL',
#   'Date': 1604514684},
#  {'City': 'paita',
#   'Lat': -5.09,
#   'Lng': -81.11,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Country': 'PE',
#   'Date': 1604514684},
#  {'City': 'cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 97,
#   'Wind Speed': 5.82,
#   'Country': 'GF',
#   'Date': 1604514685},
#  {'City': 'cabo san lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 87.01,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'MX',
#   'Date': 1604514685},
#  {'City': 'severo-kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 36.52,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 27.22,
#   'Country': 'RU',
#   'Date': 1604514685},
#  {'City': 'abashiri',
#   'Lat': 44.02,
#   'Lng': 144.27,
#   'Max Temp': 37.99,
#   'Humidity': 69,
#   'Cloudiness': 52,
#   'Wind Speed': 1.99,
#   'Country': 'JP',
#   'Date': 1604514685},
#  {'City': 'taltal',
#   'Lat': -25.4,
#   'Lng': -70.48,
#   'Max Temp': 63.81,
#   'Humidity': 61,
#   'Cloudiness': 27,
#   'Wind Speed': 7.56,
#   'Country': 'CL',
#   'Date': 1604514685},
#  {'City': 'hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 51.8,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 19.46,
#   'Country': 'IS',
#   'Date': 1604514685},
#  {'City': 'necochea',
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 78.01,
#   'Humidity': 44,
#   'Cloudiness': 95,
#   'Wind Speed': 25.01,
#   'Country': 'AR',
#   'Date': 1604514686},
#  {'City': 'bara',
#   'Lat': 10.37,
#   'Lng': 10.73,
#   'Max Temp': 86,
#   'Humidity': 33,
#   'Cloudiness': 51,
#   'Wind Speed': 9.17,
#   'Country': 'NG',
#   'Date': 1604514686},
#  {'City': 'esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': 1604514686},
#  {'City': 'eston',
#   'Lat': 51.15,
#   'Lng': -108.75,
#   'Max Temp': 55.4,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'CA',
#   'Date': 1604514602},
#  {'City': 'krasnyy chikoy',
#   'Lat': 50.36,
#   'Lng': 108.75,
#   'Max Temp': 26.4,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'RU',
#   'Date': 1604514686},
#  {'City': 'udachnyy',
#   'Lat': 66.42,
#   'Lng': 112.4,
#   'Max Temp': -4,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': 1604514686},
#  {'City': 'maridi',
#   'Lat': 4.92,
#   'Lng': 29.47,
#   'Max Temp': 71.87,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 1.68,
#   'Country': 'SS',
#   'Date': 1604514686},
#  {'City': 'port lincoln',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 80,
#   'Wind Speed': 11.05,
#   'Country': 'AU',
#   'Date': 1604514686},
#  {'City': 'buala',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 81.19,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Country': 'SB',
#   'Date': 1604514687},
#  {'City': 'narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'GL',
#   'Date': 1604514687},
#  {'City': 'scalea',
#   'Lat': 39.81,
#   'Lng': 15.8,
#   'Max Temp': 62.69,
#   'Humidity': 70,
#   'Cloudiness': 19,
#   'Wind Speed': 2.21,
#   'Country': 'IT',
#   'Date': 1604514687},
#  {'City': 'mogadishu',
#   'Lat': 2.04,
#   'Lng': 45.34,
#   'Max Temp': 79.27,
#   'Humidity': 84,
#   'Cloudiness': 44,
#   'Wind Speed': 12.73,
#   'Country': 'SO',
#   'Date': 1604514687},
#  {'City': 'yar-sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 21.76,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Country': 'RU',
#   'Date': 1604514678},
#  {'City': 'ola',
#   'Lat': 59.58,
#   'Lng': 151.28,
#   'Max Temp': 15.78,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 16.17,
#   'Country': 'RU',
#   'Date': 1604514687},
#  {'City': 'mamallapuram',
#   'Lat': 12.63,
#   'Lng': 80.17,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'IN',
#   'Date': 1604514687},
#  {'City': 'idlib',
#   'Lat': 35.93,
#   'Lng': 36.63,
#   'Max Temp': 60.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'SY',
#   'Date': 1604514687},
#  {'City': 'saint-augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 29.46,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 18.86,
#   'Country': 'CA',
#   'Date': 1604514688},
#  {'City': 'dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 76.06,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Country': 'PH',
#   'Date': 1604514688},
#  {'City': 'faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 79.61,
#   'Humidity': 79,
#   'Cloudiness': 94,
#   'Wind Speed': 16.53,
#   'Country': 'PF',
#   'Date': 1604514688},
#  {'City': 'belen',
#   'Lat': 36.49,
#   'Lng': 36.22,
#   'Max Temp': 60.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'TR',
#   'Date': 1604514688},
#  {'City': 'coracao de jesus',
#   'Lat': -16.69,
#   'Lng': -44.37,
#   'Max Temp': 78.8,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 2.17,
#   'Country': 'BR',
#   'Date': 1604514688},
#  {'City': 'ponta do sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Country': 'PT',
#   'Date': 1604514688},
#  {'City': 'contramaestre',
#   'Lat': 20.3,
#   'Lng': -76.24,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CU',
#   'Date': 1604514688},
#  {'City': 'kamenka',
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 42.01,
#   'Humidity': 94,
#   'Cloudiness': 50,
#   'Wind Speed': 6.98,
#   'Country': 'RU',
#   'Date': 1604514688},
#  {'City': 'mount isa',
#   'Lat': -20.73,
#   'Lng': 139.5,
#   'Max Temp': 75.2,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': 1604514643},
#  {'City': 'beian',
#   'Lat': 63.66,
#   'Lng': 9.57,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 31.09,
#   'Country': 'NO',
#   'Date': 1604514688},
#  {'City': 'sosva',
#   'Lat': 59.18,
#   'Lng': 61.86,
#   'Max Temp': 35.2,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 9.55,
#   'Country': 'RU',
#   'Date': 1604514689},
#  {'City': 'pueblo nuevo',
#   'Lat': 23.38,
#   'Lng': -105.38,
#   'Max Temp': 79.43,
#   'Humidity': 31,
#   'Cloudiness': 34,
#   'Wind Speed': 3.56,
#   'Country': 'MX',
#   'Date': 1604514689},
#  {'City': 'bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 18.34,
#   'Country': 'BB',
#   'Date': 1604514689},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.39,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.36,
#   'Country': 'MV',
#   'Date': 1604514689},
#  {'City': 'hovd',
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 23.09,
#   'Humidity': 92,
#   'Cloudiness': 2,
#   'Wind Speed': 2.26,
#   'Country': 'MN',
#   'Date': 1604514689},
#  {'City': 'huancavelica',
#   'Lat': -12.77,
#   'Lng': -74.98,
#   'Max Temp': 51.82,
#   'Humidity': 52,
#   'Cloudiness': 49,
#   'Wind Speed': 8.63,
#   'Country': 'PE',
#   'Date': 1604514689},
#  {'City': 'mukhen',
#   'Lat': 48.1,
#   'Lng': 136.1,
#   'Max Temp': 25.52,
#   'Humidity': 86,
#   'Cloudiness': 93,
#   'Wind Speed': 12.03,
#   'Country': 'RU',
#   'Date': 1604514689},
#  {'City': 'rossland',
#   'Lat': 49.08,
#   'Lng': -117.8,
#   'Max Temp': 44.01,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'CA',
#   'Date': 1604514645},
#  {'City': 'ust-barguzin',
#   'Lat': 53.45,
#   'Lng': 108.98,
#   'Max Temp': 28.74,
#   'Humidity': 92,
#   'Cloudiness': 56,
#   'Wind Speed': 10.2,
#   'Country': 'RU',
#   'Date': 1604514690},
#  {'City': 'tilichiki',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': 34.07,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 24.87,
#   'Country': 'RU',
#   'Date': 1604514690},
#  {'City': 'college',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': -27.4,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 1.07,
#   'Country': 'US',
#   'Date': 1604514690},
#  {'City': 'brumadinho',
#   'Lat': -20.14,
#   'Lng': -44.2,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Date': 1604514690},
#  {'City': 'zemaiciu naumiestis',
#   'Lat': 55.36,
#   'Lng': 21.7,
#   'Max Temp': 49.03,
#   'Humidity': 75,
#   'Cloudiness': 58,
#   'Wind Speed': 11.99,
#   'Country': 'LT',
#   'Date': 1604514690},
#  {'City': 'kendari',
#   'Lat': -3.94,
#   'Lng': 122.5,
#   'Max Temp': 76.46,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Country': 'ID',
#   'Date': 1604514690},
#  {'City': 'iralaya',
#   'Lat': 15,
#   'Lng': -83.23,
#   'Max Temp': 79.95,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Country': 'HN',
#   'Date': 1604514690},
#  {'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 5.41,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Country': 'RU',
#   'Date': 1604514691},
#  {'City': 'chiredzi',
#   'Lat': -21.05,
#   'Lng': 31.67,
#   'Max Temp': 71.91,
#   'Humidity': 78,
#   'Cloudiness': 82,
#   'Wind Speed': 3.74,
#   'Country': 'ZW',
#   'Date': 1604514691},
#  {'City': 'axim',
#   'Lat': 4.87,
#   'Lng': -2.24,
#   'Max Temp': 79.99,
#   'Humidity': 82,
#   'Cloudiness': 72,
#   'Wind Speed': 5.79,
#   'Country': 'GH',
#   'Date': 1604514691},
#  {'City': 'jalu',
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 66.18,
#   'Humidity': 61,
#   'Cloudiness': 45,
#   'Wind Speed': 8.3,
#   'Country': 'LY',
#   'Date': 1604514691},
#  {'City': 'kulhudhuffushi',
#   'Lat': 6.62,
#   'Lng': 73.07,
#   'Max Temp': 82.24,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 2.15,
#   'Country': 'MV',
#   'Date': 1604514691},
#  {'City': 'grand gaube',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 73,
#   'Humidity': 70,
#   'Cloudiness': 73,
#   'Wind Speed': 5.01,
#   'Country': 'MU',
#   'Date': 1604514691},
#  {'City': 'okha',
#   'Lat': 53.57,
#   'Lng': 142.95,
#   'Max Temp': 27.54,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 26.17,
#   'Country': 'RU',
#   'Date': 1604514691},
#  {'City': 'ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 80.11,
#   'Humidity': 80,
#   'Cloudiness': 24,
#   'Wind Speed': 2.75,
#   'Country': 'ID',
#   'Date': 1604514692},
#  {'City': 'andenes',
#   'Lat': 69.31,
#   'Lng': 16.12,
#   'Max Temp': 42.01,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'NO',
#   'Date': 1604514692},
#  {'City': 'leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 3.7,
#   'Humidity': 78,
#   'Cloudiness': 72,
#   'Wind Speed': 7.56,
#   'Country': 'RU',
#   'Date': 1604514692},
#  {'City': 'souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'MU',
#   'Date': 1604514692},
#  {'City': 'gizo',
#   'Lat': -8.1,
#   'Lng': 156.84,
#   'Max Temp': 82.63,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Country': 'SB',
#   'Date': 1604514693},
#  {'City': 'cockburn town',
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'TC',
#   'Date': 1604514693},
#  {'City': 'flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 66.99,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Date': 1604514693},
#  {'City': 'lanxi',
#   'Lat': 29.22,
#   'Lng': 119.48,
#   'Max Temp': 52.43,
#   'Humidity': 81,
#   'Cloudiness': 38,
#   'Wind Speed': 3.83,
#   'Country': 'CN',
#   'Date': 1604514693},
#  {'City': 'francisco sa',
#   'Lat': -16.48,
#   'Lng': -43.49,
#   'Max Temp': 78.8,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 2.51,
#   'Country': 'BR',
#   'Date': 1604514693},
#  {'City': 'novyy urengoy',
#   'Lat': 66.08,
#   'Lng': 76.63,
#   'Max Temp': 11.61,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31,
#   'Country': 'RU',
#   'Date': 1604514693},
#  {'City': 'sorland',
#   'Lat': 67.67,
#   'Lng': 12.69,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Country': 'NO',
#   'Date': 1604514694},
#  {'City': 'baculin',
#   'Lat': 7.45,
#   'Lng': 126.58,
#   'Max Temp': 77.9,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'PH',
#   'Date': 1604514694},
#  {'City': 'honningsvag',
#   'Lat': 70.98,
#   'Lng': 25.97,
#   'Max Temp': 39.2,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Country': 'NO',
#   'Date': 1604514694},
#  {'City': 'victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 72,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 19.1,
#   'Country': 'HK',
#   'Date': 1604514397},
#  {'City': 'shaturtorf',
#   'Lat': 55.57,
#   'Lng': 39.42,
#   'Max Temp': 41.2,
#   'Humidity': 94,
#   'Cloudiness': 73,
#   'Wind Speed': 5.73,
#   'Country': 'RU',
#   'Date': 1604514694},
#  {'City': 'port blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 80.89,
#   'Humidity': 79,
#   'Cloudiness': 5,
#   'Wind Speed': 4.9,
#   'Country': 'IN',
#   'Date': 1604514694},
#  {'City': 'tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 63.86,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 0.65,
#   'Country': 'IN',
#   'Date': 1604514695},
#  {'City': 'bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 75.49,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'ID',
#   'Date': 1604514695},
#  {'City': 'ucluelet',
#   'Lat': 48.93,
#   'Lng': -125.55,
#   'Max Temp': 54,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Country': 'CA',
#   'Date': 1604514664},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'PE',
#   'Date': 1604514695},
#  {'City': 'zalantun',
#   'Lat': 48,
#   'Lng': 122.72,
#   'Max Temp': 25.11,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Country': 'CN',
#   'Date': 1604514695},
#  {'City': 'reyes',
#   'Lat': -14.32,
#   'Lng': -67.38,
#   'Max Temp': 100.4,
#   'Humidity': 37,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'BO',
#   'Date': 1604514695},
#  {'City': 'poya',
#   'Lat': -21.35,
#   'Lng': 165.15,
#   'Max Temp': 72.03,
#   'Humidity': 84,
#   'Cloudiness': 61,
#   'Wind Speed': 2.68,
#   'Country': 'NC',
#   'Date': 1604514695},
#  {'City': 'gogrial',
#   'Lat': 8.53,
#   'Lng': 28.1,
#   'Max Temp': 82.71,
#   'Humidity': 51,
#   'Cloudiness': 58,
#   'Wind Speed': 2.8,
#   'Country': 'SS',
#   'Date': 1604514696},
#  {'City': 'rohatyn',
#   'Lat': 49.41,
#   'Lng': 24.61,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Country': 'UA',
#   'Date': 1604514696},
#  {'City': 'lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 69.8,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 8.86,
#   'Country': 'US',
#   'Date': 1604514450},
#  {'City': 'mancio lima',
#   'Lat': -7.61,
#   'Lng': -72.9,
#   'Max Temp': 95,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'BR',
#   'Date': 1604514696},
#  {'City': 'naryan-mar',
#   'Lat': 67.67,
#   'Lng': 53.09,
#   'Max Temp': 33.51,
#   'Humidity': 94,
#   'Cloudiness': 34,
#   'Wind Speed': 11.07,
#   'Country': 'RU',
#   'Date': 1604514696},
#  {'City': 'manzil salim',
#   'Lat': 35.86,
#   'Lng': 8.48,
#   'Max Temp': 64.4,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'TN',
#   'Date': 1604514696},
#  {'City': 'rio grande',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 69.8,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'BR',
#   'Date': 1604514626},
#  {'City': 'rio rancho',
#   'Lat': 35.23,
#   'Lng': -106.66,
#   'Max Temp': 69.01,
#   'Humidity': 27,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
# ...
#   'Cloudiness': 100,
#   'Wind Speed': 0.69,
#   'Country': 'CN',
#   'Date': 1604514734},
#  {'City': 'menongue',
#   'Lat': -14.66,
#   'Lng': 17.69,
#   'Max Temp': 73.08,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 6.15,
#   'Country': 'AO',
#   'Date': 1604514735},
#  {'City': 'alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 14,
#   'Wind Speed': 12.75,
#   'Country': 'NU',
#   'Date': 1604514735},
#  {'City': 'tefe',
#   'Lat': -3.35,
#   'Lng': -64.71,
#   'Max Temp': 95,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': 1604514735},
#  {'City': 'yumen',
#   'Lat': 40.28,
#   'Lng': 97.2,
#   'Max Temp': 36.7,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 16.58,
#   'Country': 'CN',
#   'Date': 1604514735},
#  {'City': 'kayunga',
#   'Lat': 0.7,
#   'Lng': 32.89,
#   'Max Temp': 66.52,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Country': 'UG',
#   'Date': 1604514735},
#  {'City': 'setermoen',
#   'Lat': 68.86,
#   'Lng': 18.35,
#   'Max Temp': 41,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'NO',
#   'Date': 1604514735},
#  {'City': 'shu',
#   'Lat': 43.6,
#   'Lng': 73.76,
#   'Max Temp': 38.5,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'KZ',
#   'Date': 1604514735},
#  {'City': 'bose',
#   'Lat': 45.46,
#   'Lng': 8.01,
#   'Max Temp': 57.99,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 0.89,
#   'Country': 'IT',
#   'Date': 1604514735},
#  {'City': 'catalina foothills',
#   'Lat': 32.3,
#   'Lng': -110.92,
#   'Max Temp': 86,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 2.73,
#   'Country': 'US',
#   'Date': 1604514736},
#  {'City': 'nchelenge',
#   'Lat': -9.35,
#   'Lng': 28.73,
#   'Max Temp': 78.04,
#   'Humidity': 61,
#   'Cloudiness': 69,
#   'Wind Speed': 3.98,
#   'Country': 'ZM',
#   'Date': 1604514736},
#  {'City': 'esmeraldas',
#   'Lat': -19.76,
#   'Lng': -44.31,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Date': 1604514736},
#  {'City': 'champerico',
#   'Lat': 14.3,
#   'Lng': -91.92,
#   'Max Temp': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'GT',
#   'Date': 1604514736},
#  {'City': 'trincomalee',
#   'Lat': 8.57,
#   'Lng': 81.23,
#   'Max Temp': 82.22,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 3.38,
#   'Country': 'LK',
#   'Date': 1604514736},
#  {'City': 'chirongui',
#   'Lat': -12.93,
#   'Lng': 45.15,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'YT',
#   'Date': 1604514736},
#  {'City': 'kaspiyskiy',
#   'Lat': 45.39,
#   'Lng': 47.37,
#   'Max Temp': 56.71,
#   'Humidity': 72,
#   'Cloudiness': 96,
#   'Wind Speed': 8.57,
#   'Country': 'RU',
#   'Date': 1604514736},
#  {'City': 'chara',
#   'Lat': 56.91,
#   'Lng': 118.26,
#   'Max Temp': 10.72,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'RU',
#   'Date': 1604514737},
#  {'City': 'la asuncion',
#   'Lat': 11.03,
#   'Lng': -63.86,
#   'Max Temp': 82.9,
#   'Humidity': 68,
#   'Cloudiness': 96,
#   'Wind Speed': 19.15,
#   'Country': 'VE',
#   'Date': 1604514737},
#  {'City': 'erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 35.29,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 9.91,
#   'Country': 'CN',
#   'Date': 1604514737},
#  {'City': 'babati',
#   'Lat': -4.22,
#   'Lng': 35.75,
#   'Max Temp': 68.54,
#   'Humidity': 66,
#   'Cloudiness': 8,
#   'Wind Speed': 5.06,
#   'Country': 'TZ',
#   'Date': 1604514737},
#  {'City': 'cheyenne',
#   'Lat': 41.14,
#   'Lng': -104.82,
#   'Max Temp': 68,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 23.04,
#   'Country': 'US',
#   'Date': 1604514582},
#  {'City': 'kismayo',
#   'Lat': -0.36,
#   'Lng': 42.55,
#   'Max Temp': 79.65,
#   'Humidity': 79,
#   'Cloudiness': 88,
#   'Wind Speed': 12.68,
#   'Country': 'SO',
#   'Date': 1604514737},
#  {'City': 'bow island',
#   'Lat': 49.87,
#   'Lng': -111.37,
#   'Max Temp': 62.6,
#   'Humidity': 48,
#   'Cloudiness': 3,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': 1604514737},
#  {'City': 'bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max Temp': 76.44,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'SO',
#   'Date': 1604514737},
#  {'City': 'pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 23.04,
#   'Country': 'TO',
#   'Date': 1604514738},
#  {'City': 'moron',
#   'Lat': -34.65,
#   'Lng': -58.62,
#   'Max Temp': 75.99,
#   'Humidity': 36,
#   'Cloudiness': 14,
#   'Wind Speed': 8.01,
#   'Country': 'AR',
#   'Date': 1604514738},
#  {'City': 'port-gentil',
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 78.21,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08,
#   'Country': 'GA',
#   'Date': 1604514738},
#  {'City': 'tsaratanana',
#   'Lat': -16.78,
#   'Lng': 47.65,
#   'Max Temp': 74.84,
#   'Humidity': 47,
#   'Cloudiness': 53,
#   'Wind Speed': 2.39,
#   'Country': 'MG',
#   'Date': 1604514738},
#  {'City': 'tornio',
#   'Lat': 65.85,
#   'Lng': 24.15,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'FI',
#   'Date': 1604514738},
#  {'City': 'dali',
#   'Lat': 25.7,
#   'Lng': 100.18,
#   'Max Temp': 54.34,
#   'Humidity': 87,
#   'Cloudiness': 23,
#   'Wind Speed': 4.45,
#   'Country': 'CN',
#   'Date': 1604514738},
#  {'City': 'henties bay',
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 8,
#   'Wind Speed': 5.86,
#   'Country': 'NA',
#   'Date': 1604514681},
#  {'City': 'gambissara',
#   'Lat': 13.24,
#   'Lng': -14.31,
#   'Max Temp': 88.48,
#   'Humidity': 39,
#   'Cloudiness': 22,
#   'Wind Speed': 4.7,
#   'Country': 'SN',
#   'Date': 1604514739},
#  {'City': 'gore',
#   'Lat': -46.1,
#   'Lng': 168.94,
#   'Max Temp': 57,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': 1604514740},
#  {'City': 'zapolyarnyy',
#   'Lat': 69.42,
#   'Lng': 30.81,
#   'Max Temp': 35.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 28.86,
#   'Country': 'RU',
#   'Date': 1604514740},
#  {'City': 'newport',
#   'Lat': 51.59,
#   'Lng': -3,
#   'Max Temp': 45,
#   'Humidity': 90,
#   'Cloudiness': 2,
#   'Wind Speed': 3.33,
#   'Country': 'GB',
#   'Date': 1604514740},
#  {'City': 'kananga',
#   'Lat': -5.9,
#   'Lng': 22.42,
#   'Max Temp': 72.91,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'CD',
#   'Date': 1604514740},
#  {'City': 'hualmay',
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 68.63,
#   'Humidity': 67,
#   'Cloudiness': 22,
#   'Wind Speed': 10.54,
#   'Country': 'PE',
#   'Date': 1604514740},
#  {'City': 'chuncheng',
#   'Lat': 22.17,
#   'Lng': 111.79,
#   'Max Temp': 65.66,
#   'Humidity': 76,
#   'Cloudiness': 91,
#   'Wind Speed': 2.48,
#   'Country': 'CN',
#   'Date': 1604514741},
#  {'City': 'la quinta',
#   'Lat': 33.66,
#   'Lng': -116.31,
#   'Max Temp': 90,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1604514677},
#  {'City': 'la rioja',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'ES',
#   'Date': 1604514741},
#  {'City': 'karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 73.08,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 8.34,
#   'Country': 'AU',
#   'Date': 1604514741},
#  {'City': 'tautira',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Country': 'PF',
#   'Date': 1604514741},
#  {'City': 'luba',
#   'Lat': 3.46,
#   'Lng': 8.55,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'GQ',
#   'Date': 1604514741},
#  {'City': 'jutai',
#   'Lat': -5.18,
#   'Lng': -68.9,
#   'Max Temp': 98.44,
#   'Humidity': 36,
#   'Cloudiness': 29,
#   'Wind Speed': 3.8,
#   'Country': 'BR',
#   'Date': 1604514741},
#  {'City': 'murmino',
#   'Lat': 54.6,
#   'Lng': 40.05,
#   'Max Temp': 46.99,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': 1604514742},
#  {'City': 'paarl',
#   'Lat': -33.73,
#   'Lng': 18.98,
#   'Max Temp': 72,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 19.46,
#   'Country': 'ZA',
#   'Date': 1604514590},
#  {'City': 'charkhari',
#   'Lat': 25.4,
#   'Lng': 79.75,
#   'Max Temp': 68,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 3.38,
#   'Country': 'IN',
#   'Date': 1604514742},
#  {'City': 'kudahuvadhoo',
#   'Lat': 2.67,
#   'Lng': 72.89,
#   'Max Temp': 82.8,
#   'Humidity': 70,
#   'Cloudiness': 42,
#   'Wind Speed': 2.91,
#   'Country': 'MV',
#   'Date': 1604514742},
#  {'City': 'saint anthony',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 68,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': 1604514742},
#  {'City': 'ust-tsilma',
#   'Lat': 65.44,
#   'Lng': 52.15,
#   'Max Temp': 38.12,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 6.8,
#   'Country': 'RU',
#   'Date': 1604514742},
#  {'City': 'urucara',
#   'Lat': -2.54,
#   'Lng': -57.76,
#   'Max Temp': 89.35,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'BR',
#   'Date': 1604514742},
#  {'City': 'maxixe',
#   'Lat': -23.86,
#   'Lng': 35.35,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'MZ',
#   'Date': 1604514742},
#  {'City': 'kentau',
#   'Lat': 43.52,
#   'Lng': 68.51,
#   'Max Temp': 46.31,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 11.48,
#   'Country': 'KZ',
#   'Date': 1604514742},
#  {'City': 'kontagora',
#   'Lat': 10.4,
#   'Lng': 5.47,
#   'Max Temp': 84.15,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Country': 'NG',
#   'Date': 1604514742},
#  {'City': 'duku',
#   'Lat': 11.24,
#   'Lng': 4.91,
#   'Max Temp': 86.22,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 8.3,
#   'Country': 'NG',
#   'Date': 1604514743},
#  {'City': 'barcelos',
#   'Lat': 41.54,
#   'Lng': -8.62,
#   'Max Temp': 55.4,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'PT',
#   'Date': 1604514743},
#  {'City': 'camopi',
#   'Lat': 3.17,
#   'Lng': -52.32,
#   'Max Temp': 83.59,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Country': 'GF',
#   'Date': 1604514743},
#  {'City': 'kungurtug',
#   'Lat': 50.6,
#   'Lng': 97.52,
#   'Max Temp': 12.24,
#   'Humidity': 90,
#   'Cloudiness': 55,
#   'Wind Speed': 2.71,
#   'Country': 'RU',
#   'Date': 1604514743},
#  {'City': 'bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 78.19,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 2.82,
#   'Country': 'ID',
#   'Date': 1604514743},
#  {'City': 'enumclaw',
#   'Lat': 47.2,
#   'Lng': -121.99,
#   'Max Temp': 63,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Country': 'US',
#   'Date': 1604514743},
#  {'City': 'ulaangom',
#   'Lat': 49.98,
#   'Lng': 92.07,
#   'Max Temp': 21.34,
#   'Humidity': 80,
#   'Cloudiness': 77,
#   'Wind Speed': 3.94,
#   'Country': 'MN',
#   'Date': 1604514744},
#  {'City': 'batemans bay',
#   'Lat': -35.72,
#   'Lng': 150.18,
#   'Max Temp': 55,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Date': 1604514744},
#  {'City': 'bima',
#   'Lat': -8.47,
#   'Lng': 118.72,
#   'Max Temp': 77.63,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 3.56,
#   'Country': 'ID',
#   'Date': 1604514744},
#  {'City': 'bonthe',
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 79.41,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 5.66,
#   'Country': 'SL',
#   'Date': 1604514744},
#  {'City': 'terre-de-bas',
#   'Lat': 15.85,
#   'Lng': -61.64,
#   'Max Temp': 84.2,
#   'Humidity': 78,
#   'Cloudiness': 48,
#   'Wind Speed': 16.11,
#   'Country': 'GP',
#   'Date': 1604514744},
#  {'City': 'chadan',
#   'Lat': 51.28,
#   'Lng': 91.58,
#   'Max Temp': 21.24,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Country': 'RU',
#   'Date': 1604514744},
#  {'City': 'scarborough',
#   'Lat': 54.28,
#   'Lng': -0.4,
#   'Max Temp': 39.99,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'GB',
#   'Date': 1604514745},
#  {'City': 'susanville',
#   'Lat': 40.42,
#   'Lng': -120.65,
#   'Max Temp': 57.2,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 3.4,
#   'Country': 'US',
#   'Date': 1604514745},
#  {'City': 'sovetskaya gavan',
#   'Lat': 48.97,
#   'Lng': 140.29,
#   'Max Temp': 25.11,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 11.45,
#   'Country': 'RU',
#   'Date': 1604514745},
#  {'City': 'sarlat-la-caneda',
#   'Lat': 44.89,
#   'Lng': 1.22,
#   'Max Temp': 44.01,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 5.7,
#   'Country': 'FR',
#   'Date': 1604514745},
#  {'City': 'banda aceh',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 79.2,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'ID',
#   'Date': 1604514745},
#  {'City': 'genc',
#   'Lat': 38.75,
#   'Lng': 40.56,
#   'Max Temp': 53.73,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Country': 'TR',
#   'Date': 1604514745},
#  {'City': 'sandwick',
#   'Lat': 60,
#   'Lng': -1.25,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 32.21,
#   'Country': 'GB',
#   'Date': 1604514745},
#  {'City': 'sao francisco de assis',
#   'Lat': -29.55,
#   'Lng': -55.13,
#   'Max Temp': 72.37,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 14.83,
#   'Country': 'BR',
#   'Date': 1604514745},
#  {'City': 'atambua',
#   'Lat': -9.11,
#   'Lng': 124.89,
#   'Max Temp': 74.89,
#   'Humidity': 80,
#   'Cloudiness': 24,
#   'Wind Speed': 3.04,
#   'Country': 'ID',
#   'Date': 1604514745},
#  {'City': 'tondano',
#   'Lat': 1.3,
#   'Lng': 124.91,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.45,
#   'Country': 'ID',
#   'Date': 1604514747},
#  {'City': 'gaziantep',
#   'Lat': 37.06,
#   'Lng': 37.38,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'TR',
#   'Date': 1604514747},
#  {'City': 'taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 79.23,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Country': 'ML',
#   'Date': 1604514747},
#  {'City': 'acandi',
#   'Lat': 8.51,
#   'Lng': -77.28,
#   'Max Temp': 86.94,
#   'Humidity': 61,
#   'Cloudiness': 55,
#   'Wind Speed': 3.98,
#   'Country': 'CO',
#   'Date': 1604514747},
#  {'City': 'zaraza',
#   'Lat': 9.35,
#   'Lng': -65.32,
#   'Max Temp': 82.81,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Country': 'VE',
#   'Date': 1604514747},
#  {'City': 'okoneshnikovo',
#   'Lat': 54.84,
#   'Lng': 75.08,
#   'Max Temp': 36.03,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 17.9,
#   'Country': 'RU',
#   'Date': 1604514747},
#  {'City': 'cap malheureux',
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 73,
#   'Humidity': 70,
#   'Cloudiness': 65,
#   'Wind Speed': 5.01,
#   'Country': 'MU',
#   'Date': 1604514748},
#  {'City': 'kargasok',
#   'Lat': 59.06,
#   'Lng': 80.86,
#   'Max Temp': 34.21,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 17.96,
#   'Country': 'RU',
#   'Date': 1604514725},
#  {'City': 'kalmunai',
#   'Lat': 7.42,
#   'Lng': 81.82,
#   'Max Temp': 79.39,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 1.14,
#   'Country': 'LK',
#   'Date': 1604514748},
#  {'City': 'pacific grove',
#   'Lat': 36.62,
#   'Lng': -121.92,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': 1604514748},
#  {'City': 'joshimath',
#   'Lat': 30.57,
#   'Lng': 79.57,
#   'Max Temp': 45.46,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Date': 1604514749},
#  {'City': 'ovsyanka',
#   'Lat': 55.96,
#   'Lng': 92.55,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': 1604514749},
#  {'City': 'dabola',
#   'Lat': 10.75,
#   'Lng': -11.12,
#   'Max Temp': 79.12,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.44,
#   'Country': 'GN',
#   'Date': 1604514749},
#  {'City': 'vila velha',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'BR',
#   'Date': 1604514750},
#  {'City': 'kyra',
#   'Lat': 49.58,
#   'Lng': 111.98,
#   'Max Temp': 24.55,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.77,
#   'Country': 'RU',
#   'Date': 1604514750},
#  {'City': 'waingapu',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 80.46,
#   'Humidity': 75,
#   'Cloudiness': 35,
#   'Wind Speed': 2.86,
#   'Country': 'ID',
#   'Date': 1604514750}]

# %%
#look at data before plotting
city_data_df.describe()
# Out:
#               Lat         Lng   Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  574.000000  574.000000  574.00000  574.000000  574.000000  574.000000
# mean    20.814321   17.421080   58.89561   70.477352   52.789199    8.454460
# std     33.283806   89.015366   23.49511   21.220163   40.168917    6.143537
# min    -54.800000 -175.200000  -27.40000   14.000000    0.000000    0.250000
# 25%     -6.535000  -58.717500   44.60000   59.000000    3.250000    3.940000
# 50%     25.425000   22.060000   65.00000   76.500000   65.500000    6.920000
# 75%     49.362500   91.625000   77.00000   86.750000   94.000000   11.410000
# max     78.220000  179.320000  100.40000  100.000000  100.000000   35.570000
#
#                Date
# count  5.740000e+02
# mean   1.604515e+09
# std    5.777541e+01
# min    1.604514e+09
# 25%    1.604515e+09
# 50%    1.604515e+09
# 75%    1.604515e+09
# max    1.604515e+09

# %% [markdown]
# # Scatter Plot latitude(x) vs. Temperature(y)
# #Scatter plot linear regression vs r

# %%
#export df to a csv file = cities
city_data_df.to_csv(output_data_file, index_label="city id")

# %%
#visiting team vs home team = x vs y standard practice
#scatter plot - latitude vs temperature
#scatter plot w/linear regression and r - value

# %%
# Add the linear regression equation and line to plot()
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
#standard linear regression template following lines(round cuts decimal to two spaces):
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
#add plot annotate to remember how to divide visual between north and south hemispheres
plt.annotate("Northern",(0,0),fontsize=10,color="black")
plt.show()

# %% [markdown]
# ## Analysis of Latitude vs Max Temperature:
# #### There appears to be a relationship between latitude and max temperature. The temperatures decrease as you move away from the equator.

# %%
# Print out the r-squared value along with the plot.(r=how good is y at explaining x)
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.44312990234108957

# %% [markdown]
# ## Analysis of Latitude vs Humidity:
# #### There appears to be a relationship between latitude and humidity. There is a clustering of more humidity as you farther north of the equator.

# %%
#y value is Humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.012134564585454142

# %% [markdown]
# ## Analysis of Latitude vs Cloudiness:
# #### There appears to be no observed relationship between latitude and cloudiness.

# %%
#y value is Cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00016681617755293673

# %% [markdown]
# ## Analysis of Latitude vs Wind Speed:
# #### There appears to be a relationship between latitude and wind speed. There are higher winds in the northern extreme latitudes above 50 degrees.

# %%
#y value is Wind Speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009631581766752344

# %% [markdown]
# # Identify northern and southern hemispheres

# %%
#visualize data to determine which column to pull from

# %%
city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         oksbol  55.63    8.29     48.99        87           0        9.17
# 1     chokurdakh  70.63  147.92    -14.19        84           0        5.84
# 2    grahamstown -33.30   26.53     60.89        93         100        9.86
# 3  mount gambier -37.83  140.77     46.40        81          40        8.05
# 4           asau  46.43   26.40     36.00        97           0        1.39
#
#   Country        Date
# 0      DK  1604514658
# 1      RU  1604514658
# 2      ZA  1604514658
# 3      AU  1604514658
# 4      RO  1604514658

# %%
#determine which column to pulll 
northern_hemisphere = city_data_df.loc[(city_data_df["Lat"] > 0)]
northern_hemisphere
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           oksbol  55.63    8.29     48.99        87           0        9.17
# 1       chokurdakh  70.63  147.92    -14.19        84           0        5.84
# 4             asau  46.43   26.40     36.00        97           0        1.39
# 5         bilibino  68.05  166.44      4.62        91         100        5.61
# 6          tobetsu  43.22  141.52     39.00        89          78       14.18
# ..             ...    ...     ...       ...       ...         ...         ...
# 567  pacific grove  36.62 -121.92     64.40        63           1        3.36
# 568      joshimath  30.57   79.57     45.46        51           0        3.44
# 569       ovsyanka  55.96   92.55     26.60        86          75       11.18
# 570         dabola  10.75  -11.12     79.12        59           0        2.44
# 572           kyra  49.58  111.98     24.55        91         100        1.77
#
#     Country        Date
# 0        DK  1604514658
# 1        RU  1604514658
# 4        RO  1604514658
# 5        RU  1604514658
# 6        JP  1604514658
# ..      ...         ...
# 567      US  1604514748
# 568      IN  1604514749
# 569      RU  1604514749
# 570      GN  1604514749
# 572      RU  1604514750
#
# [392 rows x 9 columns]

# %%
southern_hemisphere = city_data_df.loc[(city_data_df["Lat"] < 0)]
southern_hemisphere
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 2               grahamstown -33.30   26.53     60.89        93         100
# 3             mount gambier -37.83  140.77     46.40        81          40
# 8                     bluff -46.60  168.33     57.00        97          79
# 9               new norfolk -42.78  147.06     45.00        69           0
# 10                   touros  -5.20  -35.46     86.00        58          20
# ..                      ...    ...     ...       ...       ...         ...
# 556  sao francisco de assis -29.55  -55.13     72.37        43           0
# 557                 atambua  -9.11  124.89     74.89        80          24
# 564          cap malheureux -19.98   57.61     73.00        70          65
# 571              vila velha -20.33  -40.29     73.40        78          90
# 573                waingapu  -9.66  120.26     80.46        75          35
#
#      Wind Speed Country        Date
# 2          9.86      ZA  1604514658
# 3          8.05      AU  1604514658
# 8          4.00      NZ  1604514659
# 9          1.01      AU  1604514659
# 10        13.87      BR  1604514659
# ..          ...     ...         ...
# 556       14.83      BR  1604514745
# 557        3.04      ID  1604514745
# 564        5.01      MU  1604514748
# 571        5.82      BR  1604514750
# 573        2.86      ID  1604514750
#
# [182 rows x 9 columns]

# %%
#when you break something into two it should be mutually exclusive so no need to do = 0

# %%
#compare northern hemisphere lat vs max temp
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7309676801074233

# %% [markdown]
# #Analysis of relationship between

# %%
#compare southern hemisphere lat vs max temp
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5312899280833143

# %%
#compare northern hemisphere lat vs humidity
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09231358137277668

# %%
#compare southern hemisphere lat vs humidity
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.002808377203001961

# %%
#compare northern hemisphere lat vs cloudiness
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.019309226305784688

# %%
#compare southern hemisphere lat vs humidity
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00010607465512922512

# %%
#compare northern hemisphere lat vs Wind Speed
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08774196442245388

# %%
#compare southern hemisphere lat vs humidity
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05926129073505103
