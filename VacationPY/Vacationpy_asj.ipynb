# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# %%
api_key = "AIzaSyCaPx7iz28m0eT8r_4J30UOY-eb3mZEUnU"
api_key
# Out:
# 'AIzaSyCaPx7iz28m0eT8r_4J30UOY-eb3mZEUnU'

# %%
gmaps.configure(api_key=api_key)

# %%
api_key
# Out:
# 'AIzaSyCaPx7iz28m0eT8r_4J30UOY-eb3mZEUnU'

# %%
#load cities csv
city_data_df = pd.read_csv("out_put/cities.csv")
city_data_df
# Out:
#      city id           City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          0         oksbol  55.63    8.29     48.99        87           0
# 1          1     chokurdakh  70.63  147.92    -14.19        84           0
# 2          2    grahamstown -33.30   26.53     60.89        93         100
# 3          3  mount gambier -37.83  140.77     46.40        81          40
# 4          4           asau  46.43   26.40     36.00        97           0
# ..       ...            ...    ...     ...       ...       ...         ...
# 569      569       ovsyanka  55.96   92.55     26.60        86          75
# 570      570         dabola  10.75  -11.12     79.12        59           0
# 571      571     vila velha -20.33  -40.29     73.40        78          90
# 572      572           kyra  49.58  111.98     24.55        91         100
# 573      573       waingapu  -9.66  120.26     80.46        75          35
#
#      Wind Speed Country        Date
# ...

# %% [markdown]
# # Heatmap of Humidity

# %%
city_data_df.dtypes
# Out:
# city id         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
#creat coordinates
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
city_data_df.head(1)
# Out:
#    city id    City    Lat   Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        0  oksbol  55.63  8.29     48.99        87           0        9.17
#
#   Country        Date
# 0      DK  1604514658

# %% [markdown]
# ### Ideal vacation spot
# * Max temp lower than 70 deg but higher than 50.
# * Wind speed less than 25 mph.
# * Zero cloudiness.
# * Drop any rows that don't contain all three conditions.

# %%
vacation_city_df = city_data_df.loc[(city_data_df["Max Temp"] < 70) & (city_data_df["Max Temp"] > 50) \
                                    & (city_data_df["Wind Speed"] < 5) \
                                    & (city_data_df["Cloudiness"] == 0).dropna()]
vacation_city_df
# Out:
#      city id          City    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 52        52  porto torres  40.84   8.40     59.00        93           0
# 98        98   debre tabor  11.85  38.02     53.44        77           0
# 256      256          tura  25.52  90.22     63.86        57           0
# 305      305      dehloran  32.69  47.27     69.03        28           0
# 319      319         talen  23.57  76.72     65.25        28           0
# 334      334     iranshahr  27.20  60.68     68.00        14           0
# 338      338          dhar  22.60  75.30     66.20        42           0
# 343      343        mandal  25.45  74.57     68.68        24           0
# 346      346     ambajogai  18.73  76.38     66.25        52           0
# 389      389     suratgarh  29.32  73.90     66.15        24           0
# 392      392       sheopur  25.67  76.70     66.45        25           0
# 398      398    dera bugti  29.03  69.15     63.93        24           0
# ...

# %%
vacation_city_df.count()
# Out:
# city id       16
# City          16
# Lat           16
# Lng           16
# Max Temp      16
# Humidity      16
# Cloudiness    16
# Wind Speed    16
# Country       16
# Date          16
# dtype: int64

# %%
#find hotels by transforming data to own df
hotel_df = vacation_city_df[["City", "Lat", "Lng", "Country"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#              City    Lat    Lng Country Hotel Name
# 52   porto torres  40.84   8.40      IT
# 98    debre tabor  11.85  38.02      ET
# 256          tura  25.52  90.22      IN
# 305      dehloran  32.69  47.27      IR
# 319         talen  23.57  76.72      IN
# 334     iranshahr  27.20  60.68      IR
# 338          dhar  22.60  75.30      IN
# 343        mandal  25.45  74.57      IN
# 346     ambajogai  18.73  76.38      IN
# 389     suratgarh  29.32  73.90      IN
# 392       sheopur  25.67  76.70      IN
# 398    dera bugti  29.03  69.15      PK
# 426        marzuq  14.40  46.47      YE
# 436         tabas  33.60  56.92      IR
# 488       kayunga   0.70  32.89      UG
# 529     charkhari  25.40  79.75      IN

# %%
#set parameters
params = {
    "radius": 5000,
    "types": "lodging",
    "key": "AIzaSyCaPx7iz28m0eT8r_4J30UOY-eb3mZEUnU"
}

#interate with for loop
for index, row in hotel_df.iterrows():
    #get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    
    #for lat and lng within a 5,000 radius find hotels that match my parameters
    params["location"] = f"{lat},{lng}"
    
    #use the search term hotel instead of latitude and longitude
               
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #make request
    name_address = requests.get(base_url, params=params)
    
    name_address = name_address.json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Field does not exist, skipping.")
        
hotel_df
# Out:
# Field does not exist, skipping.
#              City    Lat    Lng Country                        Hotel Name
# 52   porto torres  40.84   8.40      IT                       Hotel Elisa
# 98    debre tabor  11.85  38.02      ET                            Tigesh
# 256          tura  25.52  90.22      IN          Hotel RIKMAN Continental
# 305      dehloran  32.69  47.27      IR    مسافرخانه قدس(عبدالله خداکرمی)
# 319         talen  23.57  76.72      IN                     Jaiswal Dhaba
# 334     iranshahr  27.20  60.68      IR                   کافی نت دانشگاه
# 338          dhar  22.60  75.30      IN          Hotel Shrinath Residency
# 343        mandal  25.45  74.57      IN               पीपी वाले हनुमान जी
# 346     ambajogai  18.73  76.38      IN                    Hotel Krushnai
# 389     suratgarh  29.32  73.90      IN                    Maharaja Hotel
# 392       sheopur  25.67  76.70      IN                   Hotel Bismillah
# ...
